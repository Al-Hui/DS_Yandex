# %% [markdown]
# # Линейные модели в машинном обучении "ЭкоФерма"

# %% [markdown]
# Вы работаете в IT-компании, которая выполняет на заказ проекты по машинному обучению.
#
# К вам обратился фермер, владелец молочного хозяйства «Вольный луг».
#
# Он хочет купить бурёнок, чтобы расширить поголовье стада коров. Для этого он заключил выгодный контракт с ассоциацией пастбищ «ЭкоФерма».
#
#
# Условия позволяют фермеру очень тщательно отобрать коров. Он определяет качество молока по строгой методике, и при этом ему нужно выполнять свой план развития молочного хозяйства.
#
# Фермер хочет, чтобы каждая бурёнка давала не менее 6000 килограммов молока в год, а её надой был вкусным — строго по его критериям, ничуть не хуже. А продавцы и технологи так и норовят приукрасить своих коровок!
# Поэтому он просит вас разработать модель машинного обучения, которая поможет ему управлять рисками и принимать объективное решение о покупке. «ЭкоФерма» готова предоставить подробные данные о своих коровах.
#
# Вам нужно создать две прогнозные модели для отбора бурёнок в поголовье:
#
# * Первая будет прогнозировать возможный удой коровы (целевой признак Удой);
# * Вторая — рассчитывать вероятность получить вкусное молоко от коровы (целевой признак Вкус молока).
#
# С помощью модели нужно отобрать коров по двум критериям:
# средний удой за год — не менее 6000 килограммов;
# молоко должно быть вкусным.
# ______________

# %% [markdown]
# **Шаг 1. Загрузите и изучите данные**
#
# Загрузить данные в датафреймы pandas. Файлы можно скачать по ссылкам в описании, они даже доступны через пути:
#
# /datasets/ferma_main.csv
#
# /datasets/ferma_dad.csv
#
# /datasets/cow_buy.csv
#
# Изучить данные.
#
# Определить, соответствуют ли они описанию задачи и изученным в прошлых спринтах стандартам оформления данных.
#
# При необходимости переименовать столбцы.
#
# **Шаг 2. Предобработка данных**
#
# Проверить данные на наличие пропусков и дубликатов.
#
# Узнать, корректны ли типы данных у каждого признака.
#
# При необходимости устранить все проблемы с данными.
#
# **Шаг 3. Исследовательский анализ данных**
#
# Провести статистический анализ всех признаков.
#
# Построить графики для каждого признака.
#
# Сделать выводы о данных:
#
# * написать, есть ли вы выбросы, необычное распределение количественных признаков или другие особенности;
# * рассказать, как мы планируем улучшить данные.
#
# **Шаг 4. Провести корреляционный анализ признаков в датасете ferma_main.csv**
#
# Изучить взаимосвязь между признаками: рассчитать коэффициенты корреляции между всеми признаками.
#
# Построить диаграммы рассеяния scatterplot для признака Удой, кг и всех количественных признаков с учётом значения категориальных признаков.
#
# Сделать выводы о взаимосвязи признаков.
#
# * Какой тип взаимосвязи между целевым и входными признаками?
# * Есть ли нелинейные связи между целевым и входными признаками?
# * Нужно ли вводить в модель дополнительные признаки, чтобы это учесть?
# * Наблюдается ли мультиколлинеарность между входными признаками?
#
# **Шаг 5. Задача регрессии**
#
# Нам предстоит обучить три модели простой линейной регрессии.
#
# Подготовить данные датасета ferma_main.csv и обучить на них первую модель LinearRegression.
#
# Использовать в качестве целевого признак Удой, кг.
#
# Отберать признаки, которые подходят для модели линейной регрессии, аргументировать выбор.
#
# Разбить данные на тренировочную и тестовую выборки.
#
# Кодировать категориальные признаки с помощью OneHotEncoder.
#
# Масштабировать количественные признаки с помощью StandardScaler.
#
# Обучить модель линейной регрессии на подготовленных данных.
#
# Оценить качество модели на тестовой выборке: рассчитайтт R², проанализировать остатки с помощью графиков.
#
# Оформить выводы, указать:
#
# * значение R² модели;
# * какие выводы следуют из анализа остатков;
# * нужны ли дополнительные исследования.
#
# Подготовить данные с учётом связи входных признаков с целевым и обучить на них вторую модель LinearRegression.
#
# Посмотреть на диаграммы рассеяния:
# * на них можно увидеть, что некоторые входные признаки связаны с целевым нелинейно.
# * Исключить нелинейность, чтобы эти признаки были информативны для линейной регрессии.
#
# Повторить шаги из пункта 1 и создайть вторую модель:
# * подготовить данные, обучить модель, оценить её качество и написать выводы.
# * Добавить в данные новый признак и обучить на них третью модель LinearRegression.
# * Добавить признак Имя Папы из файла ferma_dad.csv, соединив его с остальными данными ferma_main.csv по ключу.
# * Устранить нелинейность между признаками.
#
# Повторить шаги из пункта 1 и создать третью модель:
# * подготовить данные,
# * обучить модель,
# * оценить её качество,
# * написать выводы.
#
# Сравнить качество трёх моделей линейной регрессии, сопоставить их R² и остатки.
#
# Оценить качество каждой модели по трём метрикам: MSE, MAE, RMSE.
#
# Выбрать лучшую модель;
#
# Указать доверительный интервал прогноза лучшей модели. Для этого рассчитать квантили ошибки модели на тренировочных данных.
#
# С помощью лучшей модели спрогнозировать удой коров, которых фермер хочет купить. Данные о них находятся в датасете cow_buy.csv.
#
# Добавите недостающие признаки ЭКЕ (Энергетическая кормовая единица), Сырой протеин, г и СПО (Сахаро-протеиновое соотношение): взять из датасета ferma_main.csv средние значения каждого из признаков и увеличить их на 5%.
#
# Выполнить подготовку данных, аналогичную той, которую делали для тренировочной выборки.
#
# Получить прогноз удоя коров.
#
# **Шаг 6. Задача классификации**
#
# Подготовить данные датасета ferma_main.csv и обучить на них модель LogisticRegression.
#
# Использовать в качестве целевого признак Вкус молока.
#
# При необходимости преобразовать имеющиеся или добавить новые признаки.
#
# Разбить данные на тренировочную и тестовую выборки.
#
# Кодировать категориальные признаки с помощью OneHotEncoder.
#
# Масштабировать количественные признаки с помощью StandardScaler.
#
# Обучить модель логистической регрессии на подготовленных данных.
#
# Оценить качество модели на тестовой выборке: рассчитать метрики accuracy, recall, precision.
#
# Построить матрицу ошибок.
#
# Проанализировать модель логистической регрессии.
#
# Объяснить, какая ошибка критичнее всего при покупке коров: первого или второго рода. Сформулировать ответ с учётом метрик recall и precision, выберать более важную из них.
#
# Свести критичную ошибку к нулю: для этого изменить порог принадлежности к классам.
#
# Ещё раз рассчитать значения метрик recall и precision.
#
# Какое значение порога выбрано?
#
# Как изменились значения метрик?
#
# Оформить выводы: сказать, что нужно сделать дальше, исходя из анализа модели?
#
# С помощью обученной модели спрогнозировать вкус молока коров, которых фермер хочет купить. Данные о них находятся в датасете cow_buy.csv.
#
# Выполнить подготовку данных, аналогичную той, которую делали для тренировочной выборки.
#
# Получить прогноз вкуса молока коров.
#
# **Шаг 7. Сделать итоговые выводы**
#
# Добавить прогнозы вкуса молока и удоя коров «ЭкоФермы» в датафрейм с коровами, покупку которых рассматривает фермер.
#
# Отберать коров, для которых спрогнозирован удой более 6000 килограммов в год и вкусное молоко.
#
# Коротко описать результаты работы моделей для фермера.
#
# Сколько коров он может купить из стада на продажу с минимальным риском для себя? Почему?
#
# Какие ещё рекомендации можно ему дать?
#
# Сделать выводы о моделях линейной регрессии и логистической регрессии.
#
# Какие способы улучшения качества регрессионной модели мы использовали в этой задаче?
#
# Возможно ли ещё улучшить результаты регрессионной модели? Если можно, то как? Если нет, то почему?
#
# Какие метрики моделей классификации, в том числе логистической регрессии, важны при анализе рисков или экономических расчётов?

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# **Шаг 1. Загрузите и изучите данные**
#
# Загрузить данные в датафреймы pandas.
#
# Файлы можно скачать по ссылкам в описании, они даже доступны через пути:
#
# /datasets/ferma_main.csv
#
# /datasets/ferma_dad.csv
#
# /datasets/cow_buy.csv
#
# Изучить данные.
# Определить, соответствуют ли они описанию задачи и изученным в прошлых спринтах стандартам оформления данных.
# При необходимости переименовать столбцы.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import (LinearRegression, 
                                  LogisticRegression)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import (StandardScaler, 
                                   OneHotEncoder)
from sklearn.metrics import (r2_score, 
                             mean_squared_error, 
                             mean_absolute_error, 
                             accuracy_score, 
                             precision_score,
                             recall_score, 
                             confusion_matrix, 
                             precision_recall_curve)
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Отлично по оформлению. Если у нас 2-3 импорта через запятую, можно оставлять без скобок и в одну строку.
#
# `from sklearn.linear_model import LinearRegression, LogisticRegression`
#
# </div>

# %%
main = pd.read_csv('/datasets/ferma_main.csv', sep=';')
dad = pd.read_csv('/datasets/ferma_dad.csv', sep=';')
cow_buy = pd.read_csv('/datasets/cow_buy.csv', sep=';')
#добавим знак разделения вручную тк пандас не понял автоматически как делить на колонки

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 12 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     634 non-null    int64
#  1   Удой, кг                               634 non-null    int64
#  2   ЭКЕ (Энергетическая кормовая единица)  634 non-null    object
#  3   Сырой протеин, г                       634 non-null    int64
#  4   СПО (Сахаро-протеиновое соотношение)   634 non-null    object
#  5   Порода                                 634 non-null    object
#  6   Тип пастбища                           634 non-null    object
#  7   порода папы_быка                       634 non-null    object
#  8   Жирность,%                             634 non-null    object
#  9   Белок,%                                634 non-null    object
# ...

# %%
dad.info()
dad.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        629 non-null    int64
#  1   Имя Папы  629 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 10.0+ KB
#    id  Имя Папы
# 0   1    Буйный
# 1   2  Соловчик
# 2   3     Барин
# 3   4    Буйный
# 4   5     Барин

# %%
cow_buy.info()
cow_buy.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Порода                   20 non-null     object
#  1   Тип пастбища             20 non-null     object
#  2   порода папы_быка         20 non-null     object
#  3   Имя_папы                 20 non-null     object
#  4   Текущая_жирность,%       20 non-null     object
#  5   Текущий_уровень_белок,%  20 non-null     object
#  6   Возраст                  20 non-null     object
# dtypes: object(7)
# memory usage: 1.2+ KB
#             Порода Тип пастбища порода папы_быка  Имя_папы Текущая_жирность,%  \
# 0   Вис Бик Айдиал    холмистое           Айдиал  Геркулес               3,58
# 1   Вис Бик Айдиал    равнинное          Соверин    Буйный               3,54
# 2  РефлешнСоверинг    равнинное          Соверин     Барин               3,59
# ...

# %%
col = ['id', 'yield_kg', 
      'efu', 'protein_g', 
      'spr', 'breed', 
      'pasture_type', 'father_breed', 
      'fat_%', 'protein_%', 
      'milk_taste', 'age']
main.columns = col

# %%
dad.columns = ['id', 'father_name']

# %%
cow_col = ['breed', 'pasture_type', 'father_breed', 'father_name', 'current_fat_%', 'current_protein_%', 'age']
cow_buy.columns = cow_col

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично по переименованию колонок. Нам будет удобнее работать с более короткими названиями признаков.
# </div>

# %% [markdown]
# В трех таблицах изменили названия колонок, приведя их к "змеинному" формату и на латиницу для удобства дальнейшей обработки, видим что пропусков значений нет, но при этом требуется изменить некоторые типы колонок это и будем делать следующим шагом.

# %% [markdown]
# ##  Предобработка данных

# %% [markdown]
# **Шаг 2. Предобработка данных**
#
# Проверить данные на наличие пропусков и дубликатов.
#
# Узнать, корректны ли типы данных у каждого признака.
#
# При необходимости устранить все проблемы с данными.

# %%
main.head()
# Out:
#    id  yield_kg   efu  protein_g    spr            breed pasture_type  \
# 0   1      5863  14,2       1743   0,89   Вис Бик Айдиал    Равнинное
# 1   2      5529  12,8       2138   0,89   Вис Бик Айдиал    Равнинные
# 2   3      5810    14       1854  0,885  РефлешнСоверинг    Холмистое
# 3   4      5895  12,4       2012  0,885  РефлешнСоверинг    Холмистое
# 4   5      5302  12,8       1675  0,885   Вис Бик Айдиал    Равнинные
#
#   father_breed fat_% protein_% milk_taste          age
# 0       Айдиал  3,58     3,076     вкусно  более_2_лет
# 1      Соверин  3,54     3,079     вкусно  менее_2_лет
# 2      Соверин  3,59     3,074  не вкусно  более_2_лет
# 3       Айдиал   3,4     3,075  не вкусно  более_2_лет
# 4      Соверин  3,73     3,073     вкусно  менее_2_лет

# %% [markdown]
# колонки 'efu', 'spr', 'fat_%', 'protein_%' содержат десятичные дроби, но вместо точки (так делают в питоне) используется запятая. Это нужно исправить и поменять тип данных.

# %%
q = ['efu', 'spr', 'fat_%', 'protein_%']
for s in q:
    main[s] = main[s].apply(lambda x: float(x.split()[0].replace(',','.')))
    main[s] = main[s].astype('float')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍  Если при загрузке определить разделитель для чисел `decimal = ','`, то это действие будет излишним. Типы данных изначально встанут корректно.
# </div>

# %%
main.info() #видим, что все сработало и тип данных изменен
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            634 non-null    int64
#  1   yield_kg      634 non-null    int64
#  2   efu           634 non-null    float64
#  3   protein_g     634 non-null    int64
#  4   spr           634 non-null    float64
#  5   breed         634 non-null    object
#  6   pasture_type  634 non-null    object
#  7   father_breed  634 non-null    object
#  8   fat_%         634 non-null    float64
#  9   protein_%     634 non-null    float64
#  10  milk_taste    634 non-null    object
#  11  age           634 non-null    object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 59.6+ KB

# %% [markdown]
# Ищем дубликаты:
#     переводим все что можно в нижни регистр

# %%
columns = list(main.columns)

for s in columns:
    if str(main[s].dtype) == 'object':
        main[s] = main[s].str.lower()
        print(main[s].value_counts(), '\n')
# Out:
# вис бик айдиал     373
# рефлешнсоверинг    261
# Name: breed, dtype: int64
#
# холмистое    356
# равнинное    253
# равнинные     25
# Name: pasture_type, dtype: int64
#
# соверин    316
# айдиал     240
# айдиалл     78
# Name: father_breed, dtype: int64
#
# вкусно       371
# не вкусно    263
# Name: milk_taste, dtype: int64
#
# более_2_лет    524
# менее_2_лет    110
# Name: age, dtype: int64

# %% [markdown]
# замечены неявные дубли, котроые потребуется переимоновать в одинаковый вид

# %%
main['pasture_type'] = main['pasture_type'].apply(lambda x: 'равнинное' if x == 'равнинные' else x)
main['pasture_type'].value_counts()
# Out:
# холмистое    356
# равнинное    278
# Name: pasture_type, dtype: int64

# %%
main['father_breed'] = main['father_breed'].apply(lambda x: 'айдиал' if x == 'айдиалл' else x)
main['father_breed'].value_counts()
# Out:
# айдиал     318
# соверин    316
# Name: father_breed, dtype: int64

# %%
main.duplicated().sum() #у нас еще есть явные дубли
# Out:
# 5

# %%
main = main.drop_duplicates().reset_index(drop=True) #убираем их

# %%
main.duplicated().sum() #явные дубли убраны
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Верно по дублям.
# </div>

# %%
main['yield_kg'].describe()
# Out:
# count      629.000000
# mean      6188.750397
# std       1644.795489
# min       5204.000000
# 25%       5751.000000
# 50%       6133.000000
# 75%       6501.000000
# max      45616.000000
# Name: yield_kg, dtype: float64

# %%
plt.hist(main['yield_kg'], bins=100)
plt.title('Распределение удоя в кг')
plt.xlabel('кг')
plt.ylabel('Частота')
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# Присутствует аномальные значения поскольку 3 квартиль 6501, отфильтруем данные которые меньше 7000 кг.

# %%
main = main.loc[main['yield_kg'] <= 7000, :]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Хорошо.
# </div>

# %%
main.isna().sum() #без пропусков
# Out:
# id              0
# yield_kg        0
# efu             0
# protein_g       0
# spr             0
# breed           0
# pasture_type    0
# father_breed    0
# fat_%           0
# protein_%       0
# milk_taste      0
# age             0
# dtype: int64

# %%
main['efu'].describe()
# Out:
# count    608.000000
# mean      14.493586
# std        1.283866
# min       10.900000
# 25%       13.500000
# 50%       14.600000
# 75%       15.600000
# max       16.800000
# Name: efu, dtype: float64

# %%
plt.hist(main['efu'], bins=100)
plt.title('Распределение ЭКЕ (Энергетическая кормовая единица)')
plt.xlabel('ЭКЕ (Энергетическая кормовая единица)')
plt.ylabel('Частота')
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# Похоже что тут все в порядке и выглядит как нормальное распределение

# %%
main['protein_g'].describe()
# Out:
# count     608.000000
# mean     1916.911184
# std       179.832584
# min      1660.000000
# 25%      1768.750000
# 50%      1876.000000
# 75%      2046.000000
# max      2349.000000
# Name: protein_g, dtype: float64

# %%
plt.hist(main['protein_g'], bins=150)
plt.title('Распределение протеина в граммах')
plt.xlabel('Протеин в граммах')
plt.ylabel('Частота')
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# Кажется что тут тоже все ок

# %%
main['spr'].describe()
# Out:
# count    608.000000
# mean       0.912056
# std        0.032208
# min        0.840000
# 25%        0.890000
# 50%        0.930000
# 75%        0.940000
# max        0.960000
# Name: spr, dtype: float64

# %%
main['fat_%'].describe()
# Out:
# count    608.000000
# mean       3.601299
# std        0.169009
# min        2.990000
# 25%        3.590000
# 50%        3.640000
# 75%        3.720000
# max        3.750000
# Name: fat_%, dtype: float64

# %% [markdown]
# С таблицей main закончили

# %%
dad.head()
# Out:
#    id father_name
# 0   1      Буйный
# 1   2    Соловчик
# 2   3       Барин
# 3   4      Буйный
# 4   5       Барин

# %%
dad['father_name'] = dad['father_name'].str.lower()
#переведем в нижний регистр

# %%
dad['father_name'].value_counts()
#неявных дублей тут нет
# Out:
# барин       240
# буйный      215
# соловчик    110
# геркулес     64
# Name: father_name, dtype: int64

# %%
dad.duplicated().sum() #явных тоже нет
# Out:
# 0

# %%
cow_buy.head()
# Out:
#              breed pasture_type father_breed father_name current_fat_%  \
# 0   Вис Бик Айдиал    холмистое       Айдиал    Геркулес          3,58
# 1   Вис Бик Айдиал    равнинное      Соверин      Буйный          3,54
# 2  РефлешнСоверинг    равнинное      Соверин       Барин          3,59
# 3  РефлешнСоверинг    холмистое       Айдиал      Буйный           3,4
# 4  РефлешнСоверинг    равнинное       Айдиал      Буйный          3,64
#
#   current_protein_%          age
# 0             3,076  более_2_лет
# 1             3,081  менее_2_лет
# 2             3,074  более_2_лет
# 3             3,061  более_2_лет
# 4             3,074  более_2_лет

# %% [markdown]
# Нужно поменять запятую на точку в колонках current_fat_%, current_protein_% и поменять типы данных

# %%
qw = ['current_fat_%', 'current_protein_%']

for s in qw:
    cow_buy[s] = cow_buy[s].apply(lambda x: float(x.split()[0].replace(',','.')))
    cow_buy[s] = cow_buy[s].astype('float')

# %%
cow_buy.info() #типы данных изменены
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   breed              20 non-null     object
#  1   pasture_type       20 non-null     object
#  2   father_breed       20 non-null     object
#  3   father_name        20 non-null     object
#  4   current_fat_%      20 non-null     float64
#  5   current_protein_%  20 non-null     float64
#  6   age                20 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 1.2+ KB

# %%
#приступаем к поиску неявых дубликатов (переводим все в нижний регистр и проверяем)
columns = list(cow_buy.columns)

for s in columns:
    if str(cow_buy[s].dtype) == 'object':
        cow_buy[s] = cow_buy[s].str.lower()
cow_buy.head()
# Out:
#              breed pasture_type father_breed father_name  current_fat_%  \
# 0   вис бик айдиал    холмистое       айдиал    геркулес           3.58
# 1   вис бик айдиал    равнинное      соверин      буйный           3.54
# 2  рефлешнсоверинг    равнинное      соверин       барин           3.59
# 3  рефлешнсоверинг    холмистое       айдиал      буйный           3.40
# 4  рефлешнсоверинг    равнинное       айдиал      буйный           3.64
#
#    current_protein_%          age
# 0              3.076  более_2_лет
# 1              3.081  менее_2_лет
# 2              3.074  более_2_лет
# 3              3.061  более_2_лет
# 4              3.074  более_2_лет

# %%
columns = list(cow_buy.columns)

for s in columns:
    if str(cow_buy[s].dtype) == 'object':
        print(cow_buy[s].value_counts(), '\n')
# Out:
# рефлешнсоверинг    11
# вис бик айдиал      9
# Name: breed, dtype: int64
#
# равнинное    11
# холмистое     9
# Name: pasture_type, dtype: int64
#
# соверин    12
# айдиал      8
# Name: father_breed, dtype: int64
#
# буйный      8
# геркулес    6
# барин       4
# соловчик    2
# Name: father_name, dtype: int64
#
# более_2_лет    15
# менее_2_лет     5
# Name: age, dtype: int64

# %%
cow_buy['current_fat_%'].describe()
# Out:
# count    20.000000
# mean      3.577500
# std       0.126818
# min       3.340000
# 25%       3.510000
# 50%       3.590000
# 75%       3.650000
# max       3.770000
# Name: current_fat_%, dtype: float64

# %%
cow_buy['current_protein_%'].describe()
# Out:
# count    20.000000
# mean      3.069500
# std       0.010339
# min       3.046000
# 25%       3.064000
# 50%       3.074000
# 75%       3.076000
# max       3.081000
# Name: current_protein_%, dtype: float64

# %%
#cow_buy.duplicated().sum() #есть явные дубли

# %%
#cow_buy = cow_buy.drop_duplicates().reset_index(drop=True) #убираем их

# %%
cow_buy.duplicated().sum() #теперь все в порядке
# Out:
# 4

# %% [markdown]
# Аномальных значений или дублей нет наблюдается

# %% [markdown]
# Вывод по данному этапу:
#
# * исправили типы данных, которые были некорретно распознаны из-за неверного разделителя десятичных дробей
# * строковые стоблцы переведены в нижний регистр
# * пропусков не было обнаружено
# * явные и неявные дубликаты были найдены и убраны
# * аномальные знаения также были убраны из таблиц

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# **Шаг 3. Исследовательский анализ данных**
#
# Провести статистический анализ всех признаков.
#
# Построить графики для каждого признака.
#
# Сделать выводы о данных:
#
# * написать, есть ли вы выбросы, необычное распределение количественных признаков или другие особенности;
# * рассказать, как мы планируем улучшить данные.
# ___________

# %%
def pie_plot(df):
    fig = plt.figure(figsize=(16, 9))
    axes = [plt.subplot2grid((2, 6), loc, colspan=2) for loc in [(0, 0), (0, 2), (0, 4), (1, 1), (1, 3)]]
    cols = ['breed', 'pasture_type', 'father_breed', 'milk_taste', 'age']
    titles = ['Соотношение пород', 'Соотношение типов пастбищ', 'Соотношение пород папы быка', 
              'Соотношение вкуса молока', 'Соотношение возрастов']
    
    for ax, col, title in zip(axes, cols, titles):
        pivot = df.pivot_table(index=col, values='id', aggfunc='count').reset_index()
        ax.pie(pivot['id'], labels=pivot[col], autopct='%.1f%%', startangle=90)
        ax.set_title(title)
    
    fig.suptitle('Все коровы', fontsize=15)
    plt.tight_layout()
    plt.show()

# %%
pie_plot(main)

# %% [markdown]
# * больше всего пород вис бик айдиал
# * в основном холмистый тип пастбищ
# * породы папы быка айдиал немного меньше, чем соверин
# * в основном молоко вкусное
# * 81.9% коров возраст более 2 лет

# %%
main.hist(bins=50, figsize=(16, 9))
plt.show()

# %% [markdown]
# На графиках удоя, efu и протеина % можно считать распределение нормальным

# %% [markdown]
# Посмотрим на числовые показатели и сравним их сразными типами

# %%
def barh_plot(df, column, title):
    ls = list(df['breed'].unique())
    
    # Определяем столбцы по типу
    ls_float = [col for col in df.select_dtypes(include='number').columns if col != 'id']
    
    fig, axes = plt.subplots(len(ls_float), 1, figsize=(9, 16))
    fig.subplots_adjust(left=0.13, right=0.93, top=0.95, bottom=0.1, wspace=0.2, hspace=0.5)
    
    width = 0.4
    
    for i, metric in enumerate(ls_float):
        pivot1 = df.loc[df['breed'] == ls[0]].pivot_table(index=column, 
                                                          values=metric, 
                                                          aggfunc='median').reset_index()
        pivot2 = df.loc[df['breed'] == ls[1]].pivot_table(index=column, 
                                                          values=metric, 
                                                          aggfunc='median').reset_index()
        
        x = np.arange(len(pivot1[column]))
        ax = axes[i]
        
        ax.barh(x + 0.2, pivot1[metric], width, label=ls[0])
        ax.barh(x - 0.2, pivot2[metric], width, label=ls[1])
        ax.set_yticks(x)
        ax.set_yticklabels(pivot1[column])
        ax.set_title(f'Медианное значение {metric} для разных пород и {title}')
        ax.set_xlabel(metric)
    
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=2)
    plt.show()

# %%
barh_plot(main, 'age', 'возраста')

# %% [markdown]
# * удой у старших коров выше, чем у молодых
# * порода рефлешносверинг дает больше молока в старшем возрасте, а молодом больший удой у пород вис бик айдаил
# * EFU выше у взрослых коров породы рефлешносверинг, а у молодых этот показатель одинаков
# * содержание белка немного выше у взрослых коров породы рефлешносверинг, а у молодых этот показатель одинаков
# * SPR одинаков у обоих пород, становится выше у более старших коров
# * содержание жира у молодых коров ниже, чем у взрослых
# * жирность молока молодых коров породы вис бик айдаил выше, чем у рефлешносверинг
# * процентное содержание белка у коров одинаково как по возрасту так и по породе

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Всё верно
#
# </div>

# %%
barh_plot(main, 'pasture_type', 'пастбищ')

# %% [markdown]
# * удой молока одинаков у обоих пород на обоих видах пастбищ
# * удой молока выше у породы рефлешнсоверинг
# * для породы вис бик айдиал EFU выше на холмистых пастбищах
# * количество протеина в молоке получается выше, если коровы пасутся на холмистых пастбищах
# * SPR, жирность и белковость молока одинакова у обоих пород в зависимости от видах пастбищ

# %%
barh_plot(main, 'milk_taste', 'вкуса молока')

# %% [markdown]
# * порода рефлешнсоверинг дает больше вкусного молока, чем порода вис бик айдикал

# %%
barh_plot(main, 'father_breed', 'папы быка')

# %% [markdown]
# * айдал имеет результаты выше, чем соверин по всем показателям кроме содержания белка в молоке
# _______________________________________________

# %% [markdown]
# **Итог по разделу main:**
#
# * больше всего пород вис бик айдиал
# * в основном холмистый тип пастбищ
# * породы папы быка айдиал немного меньше, чем соверин
# * в основном молоко вкусное
# * 81.9% коров возраст более 2 лет
#
# * удой у старших коров выше, чем у молодых
# * EFU выше у взрослых коров породы рефлешносверинг, а у молодых этот показатель одинаков
# * содержание белка немного выше у взрослых коров породы рефлешносверинг, а у молодых этот показатель одинаков
# * SPR одинаков у обоих пород, становится выше у более старших коров
# * содержание жира у молодых коров ниже, чем у взрослых
# * процентное содержание белка у коров одинаково как по возрасту так и по породе
# * удой молока одинаков у обоих пород на обоих видах пастбищ
# * порода рефлешносверинг дает больше молока в старшем возрасте, а в молодом больший удой у пород вис бик айдаил
# * удой молока выше у породы рефлешнсоверинг
# * порода рефлешнсоверинг дает больше вкусного молока, чем порода вис бик айдикал
# * жирность молока молодых коров породы вис бик айдаил выше, чем у рефлешносверинг
# * для породы вис бик айдиал EFU выше на холмистых пастбищах
# * количество протеина в молоке получается выше, если коровы пасутся на холмистых пастбищах
# * SPR, жирность и белковость молока одинакова у обоих пород в зависимости от видах пастбищ
# * айдал имеет результаты выше, чем соверин по всем показателям, кроме белка в молоке
#
# Наши данные имеют две категории (два вида пород), так что будет использовать бинарную кодировку

# %%
dad_pivot = (dad.pivot_table(index='father_name', values='id', aggfunc='count')
             .reset_index()
             .sort_values(by='id', ascending=False))
plt.pie(dad_pivot['id'], labels=dad_pivot['father_name'], autopct='%.1f%%')
plt.title('Соотношение пап быков для всех коров')
# Out:
# Text(0.5, 1.0, 'Соотношение пап быков для всех коров')

# %% [markdown]
# * у барина (38.2%) и буйного (34.2%) больше всего потомков
# * У соловчика и геркулеса по 17.5% и 10.2% потомства

# %%
def pie_plot_buy(df):
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.delaxes(axes[1, 2])  # удаляем лишний пустой график

    columns = ['breed', 'pasture_type', 'father_breed', 'father_name', 'age']
    titles = ['Соотношение пород', 'Соотношение типов пастбищ', 'Соотношение пород папы быка', 
              'Соотношение пап быков', 'Соотношение возрастов']
    
    for ax, col, title in zip(axes.flatten(), columns, titles):
        pivot = df[col].value_counts()
        ax.pie(pivot, labels=pivot.index, autopct='%.1f%%')
        ax.set_title(title)
    
    fig.suptitle('Коровы на покупку', fontsize=15)
    plt.tight_layout(rect=[0, 0, 1, 0.95])  # подгоняем размеры графиков
    plt.show()

# %%
pie_plot_buy(cow_buy.reset_index())

# %% [markdown]
# * Пород вис бик айдиал и рефлешнсоверинг одинаково на покупку
# * Поровну типы пастбищ
# * Пап быков соверин больше (62.5%), чем айдиал (37.5%)
# * Больше всего коров у которых папа бык Буйный(43.8%) и Геркулес (31.2%), Соловчик и Барин по 12.5%
# * В основном возраст коров более 2 лет 68.8%

# %%
plt.hist(cow_buy['current_fat_%'], bins=70)
plt.xlabel('Жирность, %')
plt.ylabel('Частота')
plt.title('Распределние процента жирности молока у коров на покупку')
plt.show()

# %% [markdown]
# Самые частые показатели жирности это 3.4%, 3.6% и 3.75%

# %%
plt.hist(cow_buy['current_protein_%'], bins=50)
plt.xlabel('Белок, %')
plt.ylabel('Частота')
plt.title('Распределние процента белка молока у коров на покупку')
plt.show()

# %% [markdown]
# В основном молоко имеет содержание белка 3.053%, 3.075 - 3.079 %, все остальные значения можем считать аномальными

# %%
def barh_plot_improved(df, column, title):
    breeds = df['breed'].unique()
      
    fig, axes = plt.subplots(2, 1, figsize=(10, 12), sharex=False)
    fig.subplots_adjust(left=0.15, right=0.9, top=0.9, bottom=0.2, hspace=0.5)

    width = 0.2  # Ширина столбцов
    colors = plt.cm.tab20(np.linspace(0, 1, len(breeds)))  # Генерация цветовой схемы

    #графики
    for i, metric in enumerate(['current_protein_%', 'current_fat_%']):
        ax = axes[i]
        x = np.arange(len(df[column].unique()))  # Индексы категорий
        
        for j, breed in enumerate(breeds):
            pivot = (df[df['breed'] == breed]
                     .pivot_table(index=column, values=metric, aggfunc='median')
                     .reindex(df[column].unique())  # Упорядочить по уникальным значениям column
                     .fillna(0))  # Заполнить пропуски нулями
            ax.barh(x + j * width - (len(breeds) * width) / 2, 
                    pivot[metric], width, label=breed, color=colors[j])
        
        ax.set_yticks(x)
        ax.set_yticklabels(df[column].unique())
        ax.set_title(f"Медианное значение {metric.replace('_', ' ')} для разных пород и {title}")
        ax.set_xlabel(f"{metric.replace('_', ' ').capitalize()}, %")
        ax.legend(title="Порода")

    plt.show()

# %%
barh_plot_improved(cow_buy, 'pasture_type', 'тип пастбищ')

# %% [markdown]
# * содержание белка у обоих пород для обеих типов пастибищ примерно одинаковое (минимально лидирует вис бик айдиал)
# * жирность на равнинных пастбищах у рефлешнсоверсинг выше, чем у вис бик айдиал
# * жирность на холмистых пастбищах у вис бик айдиал выше, чем у рефлешнсоверсинг

# %%
barh_plot_improved(cow_buy, 'father_breed', 'папы быка')

# %% [markdown]
# * значение белка у обеих пород пап быков и самих коров не различаются
# * у вис бик айдиал жирность ниже у породы папы Соверин, у Айдиал ситуация наоборот

# %%
barh_plot_improved(cow_buy, 'age', 'возраста')

# %% [markdown]
# * содержание белка у обеих пород и возраста практически не различаются
# * жирность молока у коров молодого возраста породы рефлешнсоверинг выше, а у старшего возраста наоборот

# %%
cow_buy_pivot = (cow_buy
                 .pivot_table(index='father_name', 
                              values=['current_fat_%', 'current_protein_%'], 
                              aggfunc='median')
                 .reset_index()
                 .sort_values(by='current_fat_%', ascending=True))

fig = plt.figure(figsize=(8, 8))
fig.subplots_adjust(hspace=0.3)

ax1 = fig.add_subplot(211)
ax1.barh(cow_buy_pivot['father_name'], cow_buy_pivot['current_fat_%'], color='skyblue')
ax1.set_title('Медианное значение жирности для разных пап быков')
ax1.set_xlabel('Жирность, %')
ax1.set_xlim(0, max(cow_buy_pivot['current_fat_%'].max(), cow_buy_pivot['current_protein_%'].max()))

for i, v in enumerate(cow_buy_pivot['current_fat_%']):
    ax1.text(v + 0.1, i, f'{v:.2f}', va='center')

ax2 = fig.add_subplot(212)
ax2.barh(cow_buy_pivot['father_name'], cow_buy_pivot['current_protein_%'], color='lightgreen')
ax2.set_title('Медианное значение белка для разных пап быков')
ax2.set_xlabel('Белок, %')
ax2.set_xlim(0, max(cow_buy_pivot['current_fat_%'].max(), cow_buy_pivot['current_protein_%'].max()))

for i, v in enumerate(cow_buy_pivot['current_protein_%']):
    ax2.text(v + 0.1, i, f'{v:.2f}', va='center')

fig.suptitle('Коровы на покупку')
plt.show()

# %% [markdown]
# * жирность молока выше у соловчика и геркулеса,а ниже всего у буйного
# * процент белка у коров в зависимости от пап быков одинаков

# %% [markdown]
# **Соберем все выводы по разделу:**
#
# * больше всего пород вис бик айдиал
# * в основном холмистый тип пастбищ
# * породы папы быка айдиал немного меньше, чем соверин
# * в основном молоко вкусное
# * 81.9% коров возраст более 2 лет
#
# * удой у старших коров выше, чем у молодых
# * EFU выше у взрослых коров породы рефлешносверинг, а у молодых этот показатель одинаков
# * содержание белка немного выше у взрослых коров породы рефлешносверинг, а у молодых этот показатель одинаков
# * SPR одинаков у обоих пород, становится выше у более старших коров
# * содержание жира у молодых коров ниже, чем у взрослых
# * процентное содержание белка у коров одинаково как по возрасту так и по породе
# * удой молока одинаков у обоих пород на обоих видах пастбищ
# * порода рефлешносверинг дает больше молока в старшем возрасте, а в молодом больший удой у пород вис бик айдаил
# * удой молока выше у породы рефлешнсоверинг
# * порода рефлешнсоверинг дает больше вкусного молока, чем порода вис бик айдикал
# * жирность молока молодых коров породы вис бик айдаил выше, чем у рефлешносверинг
# * для породы вис бик айдиал EFU выше на холмистых пастбищах
# * количество протеина в молоке получается выше, если коровы пасутся на холмистых пастбищах
# * SPR, жирность и белковость молока одинакова у обоих пород в зависимости от видах пастбищ
# * айдал имеет результаты выше, чем соверин по всем показателям, кроме белка в молоке
# * у барина (38.2%) и буйного (34.2%) больше всего потомков
# * у соловчика и геркулеса по 17.5% и 10.2% потомства
# * пород вис бик айдиал и рефлешнсоверинг одинаково на покупку
# * поровну типы пастбищ
# * пап быков соверин больше (62.5%), чем айдиал (37.5%)
# * больше всего коров у которых папа бык Буйный(43.8%) и Геркулес (31.2%), Соловчик и Барин по 12.5%
# * в основном возраст коров более 2 лет 68.8%
# * самые частые показатели жирности это 3.4% и 3.75%
# * в основном молоко имеет содержание белка 3.053%, 3.075 - 3.079 %
# * содержание белка у обоих пород для обеих типов пастибищ примерно одинаковое (минимально лидирует вис бик айдиал)
# * жирность на равнинных пастбищах у рефлешнсоверсинг выше, чем у вис бик айдиал
# * жирность на холмистых пастбищах у вис бик айдиал выше, чем у рефлешнсоверсинг
# * значение белка у обеих пород пап быков и самих коров не различаются
# * у вис бик айдиал жирность ниже у породы папы Соверин, у Айдиал ситуация наоборот
# * содержание белка у обеих пород и возраста практически не различаются
# * жирность молока у коров молодого возраста породы рефлешнсоверинг выше, а у старшего возраста наоборот
# * жирность молока выше у соловчика и геркулеса,а ниже всего у буйного
# * процент белка у коров в зависимости от пап быков одинаков
#
# _____
# Наши данные имеют две категории (два вида пород), так что будет использовать бинарную кодировку
#
# Также мы отметили самые частовстречающиеся значения и выявили аномальные показатели

# %% [markdown]
# ## Корреляционный анализ

# %% [markdown]
# **Шаг 4. Провести корреляционный анализ признаков в датасете ferma_main.csv**
#
# Изучить взаимосвязь между признаками: рассчитать коэффициенты корреляции между всеми признаками.
#
# Построить диаграммы рассеяния scatterplot для признака Удой, кг и всех количественных признаков с учётом значения категориальных признаков.
#
# Сделать выводы о взаимосвязи признаков.
#
# * Какой тип взаимосвязи между целевым и входными признаками?
# * Есть ли нелинейные связи между целевым и входными признаками?
# * Нужно ли вводить в модель дополнительные признаки, чтобы это учесть?
# * Наблюдается ли мультиколлинеарность между входными признаками?

# %%
ls_float = [col for col in main.select_dtypes(include='number').columns if col != 'id']
ls_float
# Out:
# ['yield_kg', 'efu', 'protein_g', 'spr', 'fat_%', 'protein_%']

# %%
plt.figure(figsize=(10, 9))
sns.heatmap(main[ls_float].corr(method='spearman'), annot=True, cmap='coolwarm')
plt.title('Матрица корреляций числовых показателей')
plt.show()

# %% [markdown]
# **Коэффициенты корреляций удоя:**
#
# * EFU, высокая
# * Протеин в граммах, слабая
# * SPR, высокая
# * Жирность, высокая
# * Протеин в процентах, очень слабая
#
# **Коэффициенты корреляций EFU:**
#
# * Протеин в граммах, слабая
# * SPR, высокая
# * Жирность, средняя
# * Протеин в процентах, очень слабая
#
# **Коэффициенты корреляций протеина в граммах:**
#
# * SPR, слабая
# * Жирность, слабая
# * Протеин в процентах, очень слабая
#
# **Коэффициенты корреляций SPR:**
#
# * Жирность, высокая
# * Протеин в процентах, очень слабая
#
# **Коэффициенты корреляций Жирности:**
#
# * Протеин в процентах, очень слабая

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Здесь все корректно.
# </div>

# %%
ls = list(main['breed'].unique())
main_breed_1 = main.loc[main['breed'] == ls[0]]
main_breed_2 = main.loc[main['breed'] == ls[1]]

fig = plt.figure(figsize=(16, 9))
fig.subplots_adjust(wspace=0.5, hspace=0.3)

# Цвета для пород
colors = ['#1f77b4', '#ff7f0e']  # Синий и оранжевый

ax1 = plt.subplot2grid(shape=(2, 6), loc=(0, 0), colspan=2)
ax1.scatter(main_breed_1['efu'], main_breed_1['yield_kg'], label=ls[0], color=colors[0], alpha=0.7)
ax1.scatter(main_breed_2['efu'], main_breed_2['yield_kg'], label=ls[1], color=colors[1], alpha=0.7)
ax1.set_ylabel('Удой, кг')
ax1.set_xlabel('ЭКЕ (Энергетическая кормовая единица)')
ax1.grid(True)

ax2 = plt.subplot2grid((2, 6), (0, 2), colspan=2)
ax2.scatter(main_breed_1['protein_g'], main_breed_1['yield_kg'], label=ls[0], color=colors[0], alpha=0.7)
ax2.scatter(main_breed_2['protein_g'], main_breed_2['yield_kg'], label=ls[1], color=colors[1], alpha=0.7)
ax2.set_ylabel('Удой, кг')
ax2.set_xlabel('Протеин, гр.')
ax2.grid(True)

ax3 = plt.subplot2grid((2, 6), (0, 4), colspan=2)
ax3.scatter(main_breed_1['spr'], main_breed_1['yield_kg'], label=ls[0], color=colors[0], alpha=0.7)
ax3.scatter(main_breed_2['spr'], main_breed_2['yield_kg'], label=ls[1], color=colors[1], alpha=0.7)
ax3.set_ylabel('Удой, кг')
ax3.set_xlabel('СПО (Сахаро-протеиновое соотношение), %')
ax3.grid(True)

ax4 = plt.subplot2grid((2, 6), (1, 1), colspan=2)
ax4.scatter(main_breed_1['fat_%'], main_breed_1['yield_kg'], label=ls[0], color=colors[0], alpha=0.7)
ax4.scatter(main_breed_2['fat_%'], main_breed_2['yield_kg'], label=ls[1], color=colors[1], alpha=0.7)
ax4.set_ylabel('Удой, кг')
ax4.set_xlabel('Жирность, %')
ax4.grid(True)

ax5 = plt.subplot2grid((2, 6), (1, 3), colspan=2)
ax5.scatter(main_breed_1['protein_%'], main_breed_1['yield_kg'], label=ls[0], color=colors[0], alpha=0.7)
ax5.scatter(main_breed_2['protein_%'], main_breed_2['yield_kg'], label=ls[1], color=colors[1], alpha=0.7)
ax5.set_ylabel('Удой, кг')
ax5.set_xlabel('Протеин, %')
ax5.grid(True)

handles, labels = ax1.get_legend_handles_labels()
fig.suptitle('Диаграмма рассеяния удоя от остальных числовых показателей', fontsize=15)
fig.legend(handles, labels, loc='upper center', ncol=2)
plt.show()

# %% [markdown]
# * присутствует нелинейная, похожа на квадратичную зависимость между входным признаком EFU и удоем
# * зависимость протеина и удоя случайная, нет признаков мультиколлинеарности
# * SPR присутствуют две когорты, которые вероятнее всего отвечают различным категориальным признакам
# * жирность, отсутствует линейная зависимость
# * протеин %, отсутсвует линейная зависимость
# _____

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Все точно по нелинейности.
# </div>

# %% [markdown]
# **ИТОГ по разделу:**
#
# **Коэффициенты корреляций удоя:**
#
# * EFU, высокая
# * Протеин в граммах, слабая
# * SPR, высокая
# * Жирность, высокая
# * Протеин в процентах, очень слабая
#
# **Коэффициенты корреляций EFU:**
#
# * Протеин в граммах, слабая
# * SPR, высокая
# * Жирность, средняя
# * Протеин в процентах, очень слабая
#
# **Коэффициенты корреляций протеина в граммах:**
#
# * SPR, слабая
# * Жирность, слабая
# * Протеин в процентах, очень слабая
#
# **Коэффициенты корреляций SPR:**
#
# * Жирность, высокая
# * Протеин в процентах, очень слабая
#
# **Коэффициенты корреляций Жирности:**
#
# * Протеин в процентах, очень слабая
# ____________
# * присутствует нелинейная, похожа на квадратичную зависимость между входным признаком EFU и удоем
# * зависимость протеина и удоя случайная, нет признаков мультиколлинеарности
# * SPR присутствуют две когорты, которые вероятнее всего отвечают различным категориальным признакам
# * жирность, отсутствует линейная зависимость
# * протеин %, отсутсвует линейная зависимость
#
# Частично мы можем убрать часть данных с жирностью и белком молока и посмотреть на точночть в следующем шаге, также нужно обработать EFU из-за квадратичной зависимости мы сделаем новый показатель возведя в квадрат EFU.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Замечатально по этому шагу.
# </div>

# %% [markdown]
# ## Обучение модели линейной регрессии

# %% [markdown]
# **Шаг 5. Задача регрессии**
#
# Нам предстоит обучить три модели простой линейной регрессии.
#
# Подготовить данные датасета ferma_main.csv и обучить на них первую модель LinearRegression.
#
# Использовать в качестве целевого признак Удой, кг.
#
# Отбирать признаки, которые подходят для модели линейной регрессии, аргументировать выбор.
#
# Разбить данные на тренировочную и тестовую выборки.
#
# Кодировать категориальные признаки с помощью OneHotEncoder.
#
# Масштабировать количественные признаки с помощью StandardScaler.
#
# Обучить модель линейной регрессии на подготовленных данных.
#
# Оценить качество модели на тестовой выборке: рассчитайтт R², проанализировать остатки с помощью графиков.
#
# Оформить выводы, указать:
#
# * значение R² модели;
# * какие выводы следуют из анализа остатков;
# * нужны ли дополнительные исследования.
#
# Подготовить данные с учётом связи входных признаков с целевым и обучить на них вторую модель LinearRegression.
#
# Посмотреть на диаграммы рассеяния:
# * на них можно увидеть, что некоторые входные признаки связаны с целевым нелинейно.
# * Исключить нелинейность, чтобы эти признаки были информативны для линейной регрессии.
#
# Повторить шаги из пункта 1 и создайть вторую модель:
# * подготовить данные, обучить модель, оценить её качество и написать выводы.
# * Добавить в данные новый признак и обучить на них третью модель LinearRegression.
# * Добавить признак Имя Папы из файла ferma_dad.csv, соединив его с остальными данными ferma_main.csv по ключу.
# * Устранить нелинейность между признаками.
#
# Повторить шаги из пункта 1 и создать третью модель:
# * подготовить данные,
# * обучить модель,
# * оценить её качество,
# * написать выводы.
#
# Сравнить качество трёх моделей линейной регрессии, сопоставить их R² и остатки.
#
# Оценить качество каждой модели по трём метрикам: MSE, MAE, RMSE.
#
# Выбрать лучшую модель;
#
# Указать доверительный интервал прогноза лучшей модели. Для этого рассчитать квантили ошибки модели на тренировочных данных.
#
# С помощью лучшей модели спрогнозировать удой коров, которых фермер хочет купить. Данные о них находятся в датасете cow_buy.csv.
#
# Добавите недостающие признаки ЭКЕ (Энергетическая кормовая единица), Сырой протеин, г и СПО (Сахаро-протеиновое соотношение): взять из датасета ferma_main.csv средние значения каждого из признаков и увеличить их на 5%.
#
# Выполнить подготовку данных, аналогичную той, которую делали для тренировочной выборки.
#
# Получить прогноз удоя коров.
# ____________
# **Первая модель:**

# %%
ls_float.remove('yield_kg')
ls_float.remove('fat_%')
ls_float.remove('protein_%')
ls_float
#список показателей для прогноза (числовые)
# Out:
# ['efu', 'protein_g', 'spr']

# %%
columns = list(main.columns)
ls_obj = []

for s in columns:
    if str(main[s].dtype) == 'object':
        ls_obj.append(s)
        
ls_obj.remove('milk_taste')
ls_obj
#список показателей для прогноза (категориальные)
# Out:
# ['breed', 'pasture_type', 'father_breed', 'age']

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Верно по признакам.
# </div>

# %%
RANDOM_STATE = 42

X = main.drop(['id', 'yield_kg'], axis=1)
y = main['yield_kg']

X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, random_state=RANDOM_STATE)

scaler = StandardScaler()
encoder = OneHotEncoder(drop='first', sparse=False)

# Масштабируем числовые признаки
X_train_scaled1 = scaler.fit_transform(X_train1[ls_float])
X_test_scaled1 = scaler.transform(X_test1[ls_float])

X_train_scaled1 = pd.DataFrame(X_train_scaled1, columns=ls_float)
X_test_scaled1 = pd.DataFrame(X_test_scaled1, columns=ls_float)

# Преобразуем категориальные признаки с помощью OneHotEncoder
X_train_ohe1 = encoder.fit_transform(X_train1[ls_obj])
X_test_ohe1 = encoder.transform(X_test1[ls_obj])
encoder_col_names1 = encoder.get_feature_names(ls_obj)

X_train_ohe1 = pd.DataFrame(X_train_ohe1, columns=encoder_col_names1)
X_test_ohe1 = pd.DataFrame(X_test_ohe1, columns=encoder_col_names1)

# Объединяем числовые и категориальные признаки
X_train_scaled_ohe1 = pd.concat([X_train_scaled1, X_train_ohe1], axis=1)
X_test_scaled_ohe1 = pd.concat([X_test_scaled1, X_test_ohe1], axis=1)

# %%
model_lr1 = LinearRegression()

model_lr1.fit(X_train_scaled_ohe1, y_train1)
predictions1 = model_lr1.predict(X_test_scaled_ohe1)

r2_score_linear1 = r2_score(y_test1, predictions1)
r2_score_linear1
# Out:
# 0.8046255260829765

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 По коду также верно.
# </div>

# %% [markdown]
# Коэффициент R^2 = 0.80 означает, что построенная модель объясняет 80% вариаций целевого показателя.
# _____
#
# **Анализ остатков линейной регрессии:**

# %%
def leftovers(y_test, predictions):
    # Создание DataFrame с истинными и предсказанными значениями
    linear_true_predictions = pd.DataFrame(y_test, columns=['yield_kg'])
    linear_true_predictions['yield_kg_pred'] = predictions
    linear_true_predictions = linear_true_predictions.reset_index()
    linear_true_predictions.columns = ['id', 'yield_kg_true', 'yield_kg_pred']
    linear_true_predictions['error'] = linear_true_predictions['yield_kg_true'] - linear_true_predictions['yield_kg_pred']

    # Вывод дополнительных метрик
    mae = linear_true_predictions['error'].abs().mean()
    rmse = (linear_true_predictions['error'] ** 2).mean() ** 0.5
    print(f"Средняя абсолютная ошибка (MAE): {mae:.2f}")
    print(f"Среднеквадратичная ошибка (RMSE): {rmse:.2f}")
    print(f"Min error: {linear_true_predictions['error'].min():.2f}")
    print(f"Max error: {linear_true_predictions['error'].max():.2f}")
    
    # Построение графиков
    fig = plt.figure(figsize=(16, 7))

    # Гистограмма распределения остатков
    ax1 = fig.add_subplot(121)
    ax1.hist(linear_true_predictions['error'], bins=100, color='skyblue', edgecolor='black')
    ax1.axvline(0, color='r', linestyle='--', label='Нулевая ошибка')
    ax1.axvline(linear_true_predictions['error'].mean(), color='g', linestyle='--', label='Средняя ошибка')
    ax1.text(linear_true_predictions['error'].mean() - 350, 7, "Средняя ошибка", color='g')
    ax1.set_xlim(linear_true_predictions['error'].min(), linear_true_predictions['error'].max())
    ax1.set_title('Распределение остатков')
    ax1.set_xlabel('Удой, кг')
    ax1.set_ylabel('Частота')
    ax1.legend()

    # Диаграмма рассеяния остатков
    ax2 = fig.add_subplot(122)
    ax2.scatter(linear_true_predictions['yield_kg_pred'], linear_true_predictions['error'], alpha=0.5)
    ax2.axhline(0, color='r', linestyle='--', label='Нулевая ошибка')
    ax2.set_title('Диаграмма рассеяния остатков')
    ax2.set_xlabel('Прогнозируемые значения удоя, кг')
    ax2.set_ylabel('Разница исходных значений и прогноза')
    ax2.legend()

    plt.show()

# %%
leftovers(y_test1, predictions1)
# Out:
# Средняя абсолютная ошибка (MAE): 161.36
# Среднеквадратичная ошибка (RMSE): 202.92
# Min error: -546.23
# Max error: 495.33

# %% [markdown]
# * (MAE) в среднем предсказания модели отклоняются от истинных значений на 161.36 кг.
# * RMSE учитывает большие отклонения сильнее, чем MAE, так как ошибки возводятся в квадрат. Значение 202.92 кг говорит о том, что при крупных ошибках модель иногда значительно отклоняется от истинных значений.
# * минимальная ошибка составила −546 кг, а максимальная 495 кг, что говорит о наличии выбросов или отдельных значений, где модель сильно ошибается. Эти экстремальные значения влияют на увеличение RMSE.
#
# * по графику распределения остатков похоже на нормальное, а средняя ошибка близка к нулю
# * по графику рассеяния он имеет форму рупора с увеличением диспресии
# ______
#
# $R^2$ : 0.80
#
# Средняя абсолютная ошибка (MAE): 161.36
#
# Среднеквадратичная ошибка (RMSE): 202.92
#
# Min error: -546.23
#
# Max error: 495.33

# %% [markdown]
# **Вторая модель:**

# %%
fig = plt.figure(figsize=(16, 9))
ax3 = plt.subplot2grid((2, 6), (0, 4), colspan=2)
ax3.scatter(main_breed_1['spr'], main_breed_1['yield_kg'], label=ls[0], color=colors[0], alpha=0.7)
ax3.scatter(main_breed_2['spr'], main_breed_2['yield_kg'], label=ls[1], color=colors[1], alpha=0.7)
ax3.set_ylabel('Удой, кг')
ax3.set_xlabel('СПО (Сахаро-протеиновое соотношение), %')
ax3.grid(True)

# %% [markdown]
# СПО и Удой связаны нелинейно. На их диаграмме рассеяния наблюдения сгруппированы в два кластера, причём есть такое значение СПО, которое можно считать границей между кластерами. Определим это значение = 0.91.
#
# Чтобы устранить нелинейность, преобразуем СПО в категориальный бинарный признак, использовав эту границу.
#
# Также ЭКЕ и Удой также связаны нелинейно. Нелинейность между ними можно исключить, если ввести новый признак ЭКЕ в квадрате.

# %%
main['efu_sq'] = main['efu']**2
main['spr_%_bi'] = main['spr'].apply(lambda x: 0 if x <= 0.91 else 1)

# %%
columns = list(main.columns)
ls_obj = []
ls_float = []

for s in columns:
    if str(main[s].dtype) == 'object':
        ls_obj.append(s)
    else:
        ls_float.append(s)
ls_float.remove('id')
ls_float.remove('spr')
ls_float.remove('efu')
ls_float.remove('fat_%')
ls_float.remove('protein_%')
ls_obj.remove('milk_taste')
ls_float.remove('yield_kg')

# %%
RANDOM_STATE = 42

X = main.drop(['id', 'yield_kg', 'spr', 'efu'], axis=1)
y = main['yield_kg']

X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, random_state=RANDOM_STATE)


scaler = StandardScaler()
encoder = OneHotEncoder(drop='first', sparse=False)

# Масштабируем числовые признаки
X_train_scaled2 = scaler.fit_transform(X_train2[ls_float])
X_test_scaled2 = scaler.transform(X_test2[ls_float])

X_train_scaled2 = pd.DataFrame(X_train_scaled2, columns=ls_float)
X_test_scaled2 = pd.DataFrame(X_test_scaled2, columns=ls_float)

# Преобразуем категориальные признаки с помощью OneHotEncoder
X_train_ohe2 = encoder.fit_transform(X_train2[ls_obj])
X_test_ohe2 = encoder.transform(X_test2[ls_obj])
encoder_col_names2 = encoder.get_feature_names(ls_obj)

X_train_ohe2 = pd.DataFrame(X_train_ohe2, columns=encoder_col_names2)
X_test_ohe2 = pd.DataFrame(X_test_ohe2, columns=encoder_col_names2)

# Объединяем числовые и категориальные признаки
X_train_scaled_ohe2 = pd.concat([X_train_scaled2, X_train_ohe2], axis=1)
X_test_scaled_ohe2 = pd.concat([X_test_scaled2, X_test_ohe2], axis=1)

# %%
model_lr2 = LinearRegression()

model_lr2.fit(X_train_scaled_ohe2, y_train2)
predictions2 = model_lr2.predict(X_test_scaled_ohe2)

r2_score_linear2 = r2_score(y_test2, predictions2)
r2_score_linear2
# Out:
# 0.8435351654090899

# %% [markdown]
# $R^2$ = 0.84

# %%
leftovers(y_test2, predictions2) #Анализ остатков
# Out:
# Средняя абсолютная ошибка (MAE): 140.73
# Среднеквадратичная ошибка (RMSE): 181.60
# Min error: -578.92
# Max error: 454.01

# %% [markdown]
# * (MAE) в среднем предсказания модели отклоняются от истинных значений на 140.7 кг.
#
# * RMSE учитывает большие отклонения сильнее, чем MAE, так как ошибки возводятся в квадрат. Значение 181.6 кг говорит о том, что при крупных ошибках модель иногда значительно отклоняется от истинных значений.
#
# * Минимальная ошибка составила −579 кг, а максимальная 454 кг, что говорит о наличии выбросов или отдельных значений, где модель сильно ошибается. Эти экстремальные значения влияют на увеличение RMSE.
#
# * По графику распределения остатков похоже на нормальное, а средняя ошибка близка к нулю.
#
# * По графику рассеяния он имеет форму рупора с увеличением диспресии
# ________________
#
# 𝑅2  : 0.84
#
# Средняя абсолютная ошибка (MAE): 140.73
#
# Среднеквадратичная ошибка (RMSE): 181.60
#
# Min error: -578.92
#
# Max error: 454.01
#
# ________________
#
# **Третья модель:**

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# По второй модели. Так как делаем нелинейные преобразования (возведение в квадрат и категоризацию), можем использовать обе пары признаков: и изначальные, и модифицированные.

# %% [markdown]
# Добавим признак Имя Папы из файла ferma_dad.csv, соединив его с остальными данными ferma_main.csv по ключу.
# Устраним нелинейность между признаками.

# %%
main_dad = pd.merge(main, dad, on='id')
main_dad.head()
# Out:
#    id  yield_kg   efu  protein_g    spr            breed pasture_type  \
# 0   1      5863  14.2       1743  0.890   вис бик айдиал    равнинное
# 1   2      5529  12.8       2138  0.890   вис бик айдиал    равнинное
# 2   3      5810  14.0       1854  0.885  рефлешнсоверинг    холмистое
# 3   4      5895  12.4       2012  0.885  рефлешнсоверинг    холмистое
# 4   5      5302  12.8       1675  0.885   вис бик айдиал    равнинное
#
#   father_breed  fat_%  protein_% milk_taste          age  efu_sq  spr_%_bi  \
# 0       айдиал   3.58      3.076     вкусно  более_2_лет  201.64         0
# 1      соверин   3.54      3.079     вкусно  менее_2_лет  163.84         0
# 2      соверин   3.59      3.074  не вкусно  более_2_лет  196.00         0
# 3       айдиал   3.40      3.075  не вкусно  более_2_лет  153.76         0
# 4      соверин   3.73      3.073     вкусно  менее_2_лет  163.84         0
#
#   father_name
# 0      буйный
# 1    соловчик
# 2       барин
# 3      буйный
# 4       барин

# %%
columns = list(main_dad.columns)
ls_obj = []
ls_float = []

for s in columns:
    if str(main_dad[s].dtype) == 'object':
        ls_obj.append(s)
    else:
        ls_float.append(s)
ls_float.remove('id')
ls_float.remove('spr')
ls_float.remove('efu')
ls_float.remove('fat_%')
ls_float.remove('protein_%')
ls_obj.remove('milk_taste')
ls_float.remove('yield_kg')

# %%
RANDOM_STATE = 42

X = main_dad.drop(['id', 'yield_kg', 'spr', 'efu'], axis=1)
y = main_dad['yield_kg']

X_train3, X_test3, y_train3, y_test3 = train_test_split(X, y, random_state=RANDOM_STATE)


scaler = StandardScaler()
encoder = OneHotEncoder(drop='first', sparse=False)

X_train_scaled3 = scaler.fit_transform(X_train3[ls_float])
X_test_scaled3 = scaler.transform(X_test3[ls_float])

X_train_scaled3 = pd.DataFrame(X_train_scaled3, columns=ls_float)
X_test_scaled3 = pd.DataFrame(X_test_scaled3, columns=ls_float)

X_train_ohe3 = encoder.fit_transform(X_train3[ls_obj])
X_test_ohe3 = encoder.transform(X_test3[ls_obj])
encoder_col_names3 = encoder.get_feature_names()

X_train_ohe3 = pd.DataFrame(X_train_ohe3, columns=encoder_col_names3)
X_test_ohe3 = pd.DataFrame(X_test_ohe3, columns=encoder_col_names3)

X_train_scaled_ohe3 = pd.concat([X_train_scaled3, X_train_ohe3], axis=1)
X_test_scaled_ohe3 = pd.concat([X_test_scaled3, X_test_ohe3], axis=1)

# %%
model_lr3 = LinearRegression()

model_lr3.fit(X_train_scaled_ohe3, y_train3)
predictions3 = model_lr3.predict(X_test_scaled_ohe3)

r2_score_linear3 = r2_score(y_test3, predictions3)
print(r2_score_linear3)
# Out:
# 0.8464403311710519

# %% [markdown]
# $R^2$ = 0.85

# %%
leftovers(y_test3, predictions3) #Анализ остатков
# Out:
# Средняя абсолютная ошибка (MAE): 139.97
# Среднеквадратичная ошибка (RMSE): 179.90
# Min error: -591.49
# Max error: 423.31

# %% [markdown]
# * (MAE) в среднем предсказания модели отклоняются от истинных значений на 139.97 кг.
#
# * RMSE учитывает большие отклонения сильнее, чем MAE, так как ошибки возводятся в квадрат. Значение 179.9 кг говорит о том, что при крупных ошибках модель иногда значительно отклоняется от истинных значений.
#
# * Минимальная ошибка составила −519 кг, а максимальная 423 кг, что говорит о наличии выбросов или отдельных значений, где модель сильно ошибается. Эти экстремальные значения влияют на увеличение RMSE.
#
# * По графику распределения остатков похоже на нормальное, при этом средняя ошибка близка к нулю.
#
# * По графику рассеяния есть несколько значительных выбросов (разница между фактическими и прогнозируемыми значениями превышает ±500 кг), которые могут ухудшать качество модели.
# ________________
#
# 𝑅2  : 0.85
#
# Средняя абсолютная ошибка (MAE): 139.97
#
# Среднеквадратичная ошибка (RMSE): 179.90
#
# Min error: -591.49
#
# Max error: 423.31

# %%
linear_models = pd.DataFrame(['Первая','Вторая','Третья'], columns=['item'])

linear_models['r2_score'] = [r2_score_linear1, r2_score_linear2, r2_score_linear3]

linear_models['mse'] = [mean_squared_error(y_test1, predictions1),
                        mean_squared_error(y_test2, predictions2), 
                        mean_squared_error(y_test3, predictions3)]

linear_models['mae'] = [mean_absolute_error(y_test1, predictions1),
                        mean_absolute_error(y_test2, predictions2),
                        mean_absolute_error(y_test3, predictions3)]

linear_models['rmse'] = linear_models['mse']**(1/2)

linear_models['residuals_mean'] = [np.mean(y_test1 - predictions1), 
                              np.mean(y_test2 - predictions2), 
                              np.mean(y_test3 - predictions3)]
linear_models
# Out:
#      item  r2_score           mse         mae        rmse  residuals_mean
# 0  Первая  0.804626  41177.995562  161.364854  202.923620       -0.422521
# 1  Вторая  0.843535  32977.226427  140.729445  181.596328        4.716547
# 2  Третья  0.846440  32364.920733  139.966704  179.902531       13.346804

# %% [markdown]
#  Можно ориентироваться на третью, так как она имеет лучшие показатели R², MSE, MAE и RMSE.

# %%
st.norm.interval(confidence=0.95, loc=np.mean(predictions3),scale=st.sem(predictions3))
#доверительный интервал первой модели
# Out:
# (6034.110291998778, 6169.222416473235)

# %% [markdown]
# 95% доверительный интервал средних лучшей модели составляет 6034.1 - 6169.2 кг.
# _________
#
# **Прогноз удоя для cow_buy:**

# %%
cow_buy = cow_buy.reset_index()
cow_buy_temp = cow_buy.copy(deep=True)

# %%
cow_buy_temp[['efu', 'protein_g', 'spr']] = main[['efu', 'protein_g', 'spr']].mean() * 1.05
cow_buy_temp['efu_sq'] = cow_buy_temp['efu']**2
cow_buy_temp['spr_%_bi'] = cow_buy_temp['spr'].apply(lambda x: 0 if x <= 91 else 1)
cow_buy_temp = cow_buy_temp.rename(columns={'index': 'id', 
                                            'current_fat_%': 'fat_%', 
                                            'current_protein_%': 'protein_%'})
#cow_buy_temp = cow_buy_temp.drop(['level_0'], axis=1)
cow_buy_temp.head()
# Out:
#    id            breed pasture_type father_breed father_name  fat_%  \
# 0   0   вис бик айдиал    холмистое       айдиал    геркулес   3.58
# 1   1   вис бик айдиал    равнинное      соверин      буйный   3.54
# 2   2  рефлешнсоверинг    равнинное      соверин       барин   3.59
# 3   3  рефлешнсоверинг    холмистое       айдиал      буйный   3.40
# 4   4  рефлешнсоверинг    равнинное       айдиал      буйный   3.64
#
#    protein_%          age        efu    protein_g       spr      efu_sq  \
# 0      3.076  более_2_лет  15.218265  2012.756743  0.957659  231.595584
# 1      3.081  менее_2_лет  15.218265  2012.756743  0.957659  231.595584
# 2      3.074  более_2_лет  15.218265  2012.756743  0.957659  231.595584
# 3      3.061  более_2_лет  15.218265  2012.756743  0.957659  231.595584
# 4      3.074  более_2_лет  15.218265  2012.756743  0.957659  231.595584
#
#    spr_%_bi
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
X_train = cow_buy_temp.drop(['id', 'efu', 'spr', 'fat_%', 'protein_%'], axis=1)
X_train_scaled = scaler.transform(X_train[ls_float])


X_train_ohe = encoder.transform(X_train[ls_obj])

encoder_col_names = encoder.get_feature_names()

X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)
X_train_scaled = pd.DataFrame(X_train_scaled, columns=ls_float)


X_train_scaled_ohe = pd.concat([X_train_scaled, X_train_ohe], axis=1)

# %%
predictions = model_lr3.predict(X_train_scaled_ohe)

cow_buy['yield_kg'] = predictions
# прогноз удоя коров, которых фермер хочет купить.

# %%
cow_buy
# Out:
#     index            breed pasture_type father_breed father_name  \
# 0       0   вис бик айдиал    холмистое       айдиал    геркулес
# 1       1   вис бик айдиал    равнинное      соверин      буйный
# 2       2  рефлешнсоверинг    равнинное      соверин       барин
# 3       3  рефлешнсоверинг    холмистое       айдиал      буйный
# 4       4  рефлешнсоверинг    равнинное       айдиал      буйный
# 5       5  рефлешнсоверинг    равнинное      соверин    геркулес
# 6       6   вис бик айдиал    холмистое       айдиал    геркулес
# 7       7   вис бик айдиал    равнинное      соверин      буйный
# 8       8  рефлешнсоверинг    равнинное      соверин       барин
# 9       9  рефлешнсоверинг    холмистое       айдиал      буйный
# 10     10   вис бик айдиал    холмистое      соверин    соловчик
# 11     11  рефлешнсоверинг    равнинное      соверин    геркулес
# 12     12   вис бик айдиал    холмистое       айдиал    геркулес
# ...

# %% [markdown]
# * обучено три модели линейной регрессии
# * проведено сравнение полученных моделей, метрики лучшей:
#     * $R^2$ : 0.85
#     * Средняя абсолютная ошибка (MAE): 139.97
#     * Среднеквадратичная ошибка (RMSE): 179.90
#     * Min error: -591.49
#     * Max error: 423.31
#     * Доверительный интервал в 95% средних лучшей модели составляет 6034.1 - 6169.2 кг.
# * проведен прогноз для коров на покупку, удой у всех коров выше 6000 кг.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Здесь все корректно.
# </div>

# %% [markdown]
# ## Обучение модели логистической регрессии

# %% [markdown]
# **Шаг 6. Задача классификации**
#
# Подготовить данные датасета ferma_main.csv и обучить на них модель LogisticRegression.
#
# Использовать в качестве целевого признак Вкус молока.
#
# При необходимости преобразовать имеющиеся или добавить новые признаки.
#
# Разбить данные на тренировочную и тестовую выборки.
#
# Кодировать категориальные признаки с помощью OneHotEncoder.
#
# Масштабировать количественные признаки с помощью StandardScaler.
#
# Обучить модель логистической регрессии на подготовленных данных.
#
# Оценить качество модели на тестовой выборке: рассчитать метрики accuracy, recall, precision.
#
# Построить матрицу ошибок.
#
# Проанализировать модель логистической регрессии.
#
# Объяснить, какая ошибка критичнее всего при покупке коров: первого или второго рода. Сформулировать ответ с учётом метрик recall и precision, выберать более важную из них.
#
# Свести критичную ошибку к нулю: для этого изменить порог принадлежности к классам.
#
# Ещё раз рассчитать значения метрик recall и precision.
#
# Какое значение порога выбрано?
#
# Как изменились значения метрик?
#
# Оформить выводы: сказать, что нужно сделать дальше, исходя из анализа модели?
#
# С помощью обученной модели спрогнозировать вкус молока коров, которых фермер хочет купить. Данные о них находятся в датасете cow_buy.csv.
#
# Выполнить подготовку данных, аналогичную той, которую делали для тренировочной выборки.
#
# Получить прогноз вкуса молока коров.
# ________

# %%
#готовим данные
main_temp = main.copy(deep=True)

columns = list(main_temp.columns)
ls_obj = []
ls_float = []

for s in columns:
    if str(main_temp[s].dtype) == 'object':
        ls_obj.append(s)
    else:
        ls_float.append(s)
        
ls_float.remove('id')
ls_float.remove('spr')
ls_float.remove('efu')
ls_float.remove('yield_kg')
ls_obj.remove('milk_taste')

# %%
RANDOM_STATE = 42

main_temp['milk_taste'] = main_temp['milk_taste'].apply(lambda x: 1 if x =='вкусно' else 0)

X = main_temp.drop(['id', 'milk_taste', 'spr', 'efu'], axis=1)
y = main_temp['milk_taste']

X_train_log, X_test_log, y_train_log, y_test_log = train_test_split(X, y, random_state=RANDOM_STATE)


scaler = StandardScaler()
encoder = OneHotEncoder(drop='first', sparse=False)

X_train_scaled_log = scaler.fit_transform(X_train_log[ls_float])
X_test_scaled_log = scaler.transform(X_test_log[ls_float])

X_train_scaled_log = pd.DataFrame(X_train_scaled_log, columns=ls_float)
X_test_scaled_log = pd.DataFrame(X_test_scaled_log, columns=ls_float)

X_train_ohe_log = encoder.fit_transform(X_train_log[ls_obj])
X_test_ohe_log = encoder.transform(X_test_log[ls_obj])
encoder_col_names_log = encoder.get_feature_names()

X_train_ohe_log = pd.DataFrame(X_train_ohe_log, columns=encoder_col_names_log)
X_test_ohe_log = pd.DataFrame(X_test_ohe_log, columns=encoder_col_names_log)

X_train_scaled_ohe_log = pd.concat([X_train_scaled_log, X_train_ohe_log], axis=1)
X_test_scaled_ohe_log = pd.concat([X_test_scaled_log, X_test_ohe_log], axis=1)

# %%
#обучаем
clf = LogisticRegression(random_state=RANDOM_STATE)
clf.fit(X_train_scaled_ohe_log, y_train_log)

predictions = clf.predict(X_test_scaled_ohe_log)

accuracy = accuracy_score(y_test_log, predictions)
recall = recall_score(y_test_log, predictions)
precision = precision_score(y_test_log, predictions)

print(f'Accuracy: {accuracy}')
print(f'Recall: {recall}')
print(f'Precision: {precision}')
# Out:
# Accuracy: 0.631578947368421
# Recall: 0.75
# Precision: 0.6764705882352942

# %% [markdown]
# * Accuracy: 63%
# * Recall: 75%
# * Precision: 68%

# %%
plt.figure(figsize=(8,7))
cm = confusion_matrix(y_test_log, predictions)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r')
plt.title('Матрица ошибок модели логической регрессии')
plt.ylabel('True label')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# Имеем 33 ошибки первого рода по отношению к 69 верноположительным предсказаниям.
#
# Более трети предсказаний положительного класса ошибочны.
#
# Необходимо минимизировать их количество.
# _______
#
# Ошибка первого рода - важнее при покупке коров, поскольку в таком случае мы рекомендуем фермеру купить коров с не вкусным молоком.
#
# Recall:
#
# В метрике задействуются ответы TP и FN. Ошибки второго рода - не критичны для нас, поскольку нет страшного в том, что мы не предложим фермеру несколько коров, у которых вкусное молоко. Гораздо хуже будет, если предложить не вкусное.
#
# Precision:
#
# В метрике задействуются ответы TP и FP. Количество FP (ошибок первого рода) нужно сводить к минимуму, так как они критичны. В таком случае можно сказать, что нам нужно максимизировать метрику Precision.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Точно. Минимизируем ложноположительные ошибки, максимизируем precision.
# </div>

# %%
y_proba = clf.predict_proba(X_test_scaled_ohe_log)[:,1]

data = pd.DataFrame(zip(y_test_log, y_proba),
             columns = ['y_test', 'y_proba']).sort_values(by='y_proba',ascending=False)

thresholds = [round(i,2) for i in np.linspace(0.5, 1, num = 15, endpoint=False)]

columns = []
thresholds_values = []
fp = []

conf_matrix = pd.DataFrame()

for i in thresholds:
    columns.append('y_pred_'+str(i))
    data['y_pred_'+str(i)] = data['y_proba'].apply(lambda x: 1 if x>=i  else 0)
    thresholds_values.append(i)
    fp.append(confusion_matrix(data['y_test'], data['y_pred_'+str(i)])[0][1])

conf_matrix['thresholds_values'] = thresholds_values
conf_matrix['FP'] = fp
conf_matrix
# Out:
#     thresholds_values  FP
# 0                0.50  33
# 1                0.53  28
# 2                0.57  22
# 3                0.60  16
# 4                0.63  14
# 5                0.67   7
# 6                0.70   5
# 7                0.73   3
# 8                0.77   2
# 9                0.80   0
# 10               0.83   0
# 11               0.87   0
# 12               0.90   0
# 13               0.93   0
# 14               0.97   0

# %% [markdown]
# При пороге = 0.8 FP равно нулю

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Ок.
# </div>

# %%
plt.figure(figsize=(8,7))
cm = confusion_matrix(y_test_log, data['y_pred_0.8'])
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r')
plt.title('Матрица ошибок модели логической регрессии')
plt.ylabel('True label')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# Тепре FP уменьшилось до 4 значений

# %%
accuracy = accuracy_score(data['y_test'], data['y_pred_0.8'])
recall = recall_score(data['y_test'], data['y_pred_0.8'])
precision = precision_score(data['y_test'], data['y_pred_0.8'])

print(f'Accuracy: {accuracy}')
print(f'Recall: {recall}')
print(f'Precision: {precision}')
# Out:
# Accuracy: 0.4605263157894737
# Recall: 0.10869565217391304
# Precision: 1.0

# %% [markdown]
# Precision = 1.0
# Теперь наша модель не порекомендует купить корову с плохим молоком

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 С большой долей вероятности она этого не сделает.
# </div>

# %%
#Прогнозируем
threshold_needful = 0.8

# %%
X_train = cow_buy_temp.drop(['id'], axis=1)

X_train_scaled = scaler.transform(X_train[ls_float])

X_train_scaled = pd.DataFrame(X_train_scaled, columns=ls_float)

X_train_ohe = encoder.transform(X_train[ls_obj])
encoder_col_names = encoder.get_feature_names()

X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names_log)

X_train_scaled_ohe = pd.concat([X_train_scaled, X_train_ohe], axis=1)

# %%
y_proba = clf.predict_proba(X_train_scaled_ohe)[:,1]

cow_buy['milk_taste'] = y_proba
cow_buy['milk_taste'] = cow_buy['milk_taste'].apply(lambda x: 1 if x>=threshold_needful else 0)
cow_buy['milk_taste'] = cow_buy['milk_taste'].apply(lambda x: 'вкусно' if x==1 else 'не вкусно')
cow_buy
# Out:
#     index            breed pasture_type father_breed father_name  \
# 0       0   вис бик айдиал    холмистое       айдиал    геркулес
# 1       1   вис бик айдиал    равнинное      соверин      буйный
# 2       2  рефлешнсоверинг    равнинное      соверин       барин
# 3       3  рефлешнсоверинг    холмистое       айдиал      буйный
# 4       4  рефлешнсоверинг    равнинное       айдиал      буйный
# 5       5  рефлешнсоверинг    равнинное      соверин    геркулес
# 6       6   вис бик айдиал    холмистое       айдиал    геркулес
# 7       7   вис бик айдиал    равнинное      соверин      буйный
# 8       8  рефлешнсоверинг    равнинное      соверин       барин
# 9       9  рефлешнсоверинг    холмистое       айдиал      буйный
# 10     10   вис бик айдиал    холмистое      соверин    соловчик
# 11     11  рефлешнсоверинг    равнинное      соверин    геркулес
# 12     12   вис бик айдиал    холмистое       айдиал    геркулес
# ...

# %% [markdown]
# * модель логической регрессиии создана и обучена
# * подобран порог принадлежности классов, на основе матрицы ошибок, равный 0.8
# * спрогнозирован вкус молока у коров на продажу

# %% [markdown]
# ## Итоговые выводы

# %% [markdown]
# **Шаг 7. Сделать итоговые выводы**
#
# Добавить прогнозы вкуса молока и удоя коров «ЭкоФермы» в датафрейм с коровами, покупку которых рассматривает фермер.
#
# Отобрать коров, для которых спрогнозирован удой более 6000 килограммов в год и вкусное молоко.
#
# Коротко описать результаты работы моделей для фермера.
#
# Сколько коров он может купить из стада на продажу с минимальным риском для себя? Почему?
#
# Какие ещё рекомендации можно ему дать?
#
# Сделать выводы о моделях линейной регрессии и логистической регрессии.
#
# Какие способы улучшения качества регрессионной модели мы использовали в этой задаче?
#
# Возможно ли ещё улучшить результаты регрессионной модели? Если можно, то как? Если нет, то почему?
#
# Какие метрики моделей классификации, в том числе логистической регрессии, важны при анализе рисков или экономических расчётов?

# %%
#отфильтруем с больши удоем коров и вкусным молоком
cow_buy_final = cow_buy.loc[(cow_buy['yield_kg'] >= 6000) & (cow_buy['milk_taste'] == 'вкусно')]
cow_buy_final
# Out:
#    index           breed pasture_type father_breed father_name  current_fat_%  \
# 0      0  вис бик айдиал    холмистое       айдиал    геркулес           3.58
# 6      6  вис бик айдиал    холмистое       айдиал    геркулес           3.58
#
#    current_protein_%          age    yield_kg milk_taste
# 0              3.076  более_2_лет  6158.40312     вкусно
# 6              3.076  более_2_лет  6158.40312     вкусно

# %% [markdown]
# Из стада на продажу были найдены подходящие к покупки коровы по предпочтениям фермера.
#
# Обучено три модели линейной регрессии
# проведено сравнение полученных моделей, оказалась третья модель самой точной, вот ее метрики:
#    * 𝑅2  : 0.85
#    * Средняя абсолютная ошибка (MAE): 139.97
#    * Среднеквадратичная ошибка (RMSE): 179.90
#    * Min error: -591.49
#    * Max error: 423.31
#    * Доверительный интервал в 95% средних лучшей модели составляет 6034.1 - 6169.2 кг.
#
# Проведен прогноз для коров на покупку, удой у всех коров выше 6000 кг.
#
# _________
# В процессе поиска более точной модели мы заметили, что СПО и Удой связаны нелинейно. На их диаграмме рассеяния наблюдения сгруппированы в два кластера, причём есть такое значение СПО, которое можно считать границей между кластерами. Определили это значение = 0.91.
# Чтобы устранить нелинейность, преобразовали СПО в категориальный бинарный признак, использовав эту границу.
# Также ЭКЕ и Удой также связаны нелинейно. Нелинейность между ними можно исключить, если ввести новый признак ЭКЕ в квадрате.
#
# Так наша модель стала давать более точный прогноз.
#
# Также, в третей моделе добавили признак Имя Папы из файла ferma_dad.csv, соединив его с остальными данными ferma_main.csv по ключу. Устранили нелинейность между признаками и удалили лишние колонки, влияющие на точность.
#
# В результате чего мы еще сильнее улучшили точность прогнозов модели
# _________
#
# С помощью логистической регрессии мы прогнозируем вкус молока и после уменьшения ошибки первого рода (чтобы не получилась рекомендация купить корову с невкусным молоком) наша модель рекомендует к покупке 2 коров.
#
#
# Для более точных прогнозов нам можно улучшить модель логистической регрессии, например, так как мы это сделали с линейной регрессией, добавить новые признаки и использовать анализ корреляции, и с посмотреть как мы с новыыми признаками смодем отбалансировать классы.
