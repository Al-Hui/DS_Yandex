# %% [markdown]
# ## **Комментарий ревьюера**
#
# Привет 👋
#
# Меня зовут Валентин, и я буду проверять твой проект. Предлагаю сразу договориться общаться на «ты», если для тебя это неуместно, то дай, пожалуйста, знать, будем общаться на «вы».
#
# ### **Краткое резюме по ревью**
#
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
#
# Видны твои старания при работе над данным проектом. Большинство основных этапов в работе сделано хорошо:
# - есть много сильных и интересных алгоритмов 🤩;
# - детально изучены многие тонкости данных;
# - здорово сделана предобработка данных;
# - качественно исследованы данные.
#
# Твоего внимания требуют:
#
# - построение единой сводной таблицы на каждом шаге (3.1–3.4);
# - пересмотр промежуточных и финального выводов.
#
# Я описал замечания в комментариях, которые помечены цветом(красным, желтым), после их доработки я смогу принять работу.
#
#
#
# Спасибо тебе за твой труд! Я на все 100% уверен, что у тебя все получится, и с нетерпением буду ждать твою работу на повторное ревью 😉
#
# </div>
#
# ### **PS:**
#
# Хочу поделиться дополнительным материалом, он бесплатный, но объемный(может уйти несколько месяцев):
# - У Тимофея Хирьянова есть [Плей-лист по алгоритмам на python](https://www.youtube.com/playlist?list=PLRDzFCPr95fK7tr47883DFUbm4GeOjjc0), это вроде просто видео-лекции, но в описании есть ссылка на лекции и практику, не стесняйся смотреть, преподаватель очень наглядно объясняет материал. На первых уроках задания могут показаться сложными, так как требует знания геометрии, не стесняйся проходить далее, будет проще)
#
#
# ### **Правила оформления:**
#
# По ходу тетрадки ты найдешь комментарии к проекту, они будут в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Постарайся учесть эти комментарии для дальнейших проектов. Я использую заголовки в комментариях, они изменят твое оглавление. Но тебе будет удобно перемещаться от комментария к комментарию. А перед перемещением проекта в портфолио просто уберешь данные комментарии.
#
# Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Я буду красить комментарии цветом:
#
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h4> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h4>
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
#
# Также жду от тебя комментарии, где вкратце опишешь изменения, которые были внесены.
# </div>
#
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h4> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h4>
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
#
# В случае изменений кода, опиши, пожалуйста, вкратце то, что изменилось. Если изменений не было, то просто опиши свои мысли на эту тему.
# </div>
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h4>
#
# Такой комментарий говорит о том, что было сделано что-то качественное и правильное 😃
#
# Я не буду ждать твоего комментария, но буду ему очень рад 🤗
# </div>
#
# Чтобы мы были на одной волне, рекомендую общаться в том же стиле 😊 Твои ответы на мои комментарии будут подкрашиваться в синий цвет.
#
# Ниже я оформил образец для твоего удобства, тебе остается только добавить после моего комментария ячейку с типом **Markdown**, скопировать туда код(чтобы увидеть код дважды, кликни на ячейку) из образца и написать свои мысли по поводу комментария.

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Напиши здесь свои мысли и идеи по поводу комментария ревьюера.
#
# </div>

# %% [markdown]
# ## **Комментарий ревьюера v2**
#
#
# ### **Краткое резюме по ревью**
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
#
# Молодец, исправлено:
# - построение единой сводной таблицы на каждом шаге (3.1–3.4).
#
# Твоего внимания требует:
# - дополнить финальный вывод.
#
#
# Буду ждать твою работу на повторное ревью 😉
#
# </div>

# %% [markdown]
# ## **Комментарий ревьюера v3**
#
#
# ### **Краткое резюме по ревью**
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
#
# Молодец, исправлено:
# - дополнен финальный вывод.
#
#
# Спасибо тебе за твой труд! Я готов принять работу. Успехов в дальнейшем обучении! 😉
#
# </div>

# %% [markdown]
# # Исследование надежности заемщиков

# %% [markdown]
# Во второй части проекта вы выполните шаги 3 и 4. Их вручную проверит ревьюер.
# Чтобы вам не пришлось писать код заново для шагов 1 и 2, мы добавили авторские решения в ячейки с кодом.

# %% [markdown]
# ## Откройте таблицу и изучите общую информацию о данных

# %% [markdown]
# **Задание 1. Импортируйте библиотеку pandas. Считайте данные из csv-файла в датафрейм и сохраните в переменную `data`. Путь к файлу:**
#
# `/datasets/data.csv`

# %%
import pandas as pd
import matplotlib.pyplot as plt

try:
    data = pd.read_csv('/datasets/data.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/data.csv')

# %% [markdown]
# **Задание 2. Выведите первые 20 строчек датафрейма `data` на экран.**

# %%
data.head(20)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# ...

# %% [markdown]
# **Задание 3. Выведите основную информацию о датафрейме с помощью метода `info()`.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Удаление пропусков

# %% [markdown]
# **Задание 4. Выведите количество пропущенных значений для каждого столбца. Используйте комбинацию двух методов.**

# %%
data.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# **Задание 5. В двух столбцах есть пропущенные значения. Один из них — `days_employed`. Пропуски в этом столбце вы обработаете на следующем этапе. Другой столбец с пропущенными значениями — `total_income` — хранит данные о доходах. На сумму дохода сильнее всего влияет тип занятости, поэтому заполнить пропуски в этом столбце нужно медианным значением по каждому типу из столбца `income_type`. Например, у человека с типом занятости `сотрудник` пропуск в столбце `total_income` должен быть заполнен медианным доходом среди всех записей с тем же типом.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['total_income'].isna()), 'total_income'] = \
    data.loc[(data['income_type'] == t), 'total_income'].median()

# %% [markdown]
# ### Обработка аномальных значений

# %% [markdown]
# **Задание 6. В данных могут встречаться артефакты (аномалии) — значения, которые не отражают действительность и появились по какой-то ошибке. таким артефактом будет отрицательное количество дней трудового стажа в столбце `days_employed`. Для реальных данных это нормально. Обработайте значения в этом столбце: замените все отрицательные значения положительными с помощью метода `abs()`.**

# %%
data['days_employed'] = data['days_employed'].abs()

# %% [markdown]
# **Задание 7. Для каждого типа занятости выведите медианное значение трудового стажа `days_employed` в днях.**

# %%
data.groupby('income_type')['days_employed'].agg('median')
# Out:
# income_type
# безработный        366413.652744
# в декрете            3296.759962
# госслужащий          2689.368353
# компаньон            1547.382223
# пенсионер          365213.306266
# предприниматель       520.848083
# сотрудник            1574.202821
# студент               578.751554
# Name: days_employed, dtype: float64

# %% [markdown]
# У двух типов (безработные и пенсионеры) получатся аномально большие значения. Исправить такие значения сложно, поэтому оставьте их как есть. Тем более этот столбец не понадобится вам для исследования.

# %% [markdown]
# **Задание 8. Выведите перечень уникальных значений столбца `children`.**

# %%
data['children'].unique()
# Out:
# array([ 1,  0,  3,  2, -1,  4, 20,  5])

# %% [markdown]
# **Задание 9. В столбце `children` есть два аномальных значения. Удалите строки, в которых встречаются такие аномальные значения из датафрейма `data`.**

# %%
data = data[(data['children'] != -1) & (data['children'] != 20)]

# %% [markdown]
# **Задание 10. Ещё раз выведите перечень уникальных значений столбца `children`, чтобы убедиться, что артефакты удалены.**

# %%
data['children'].unique()
# Out:
# array([1, 0, 3, 2, 4, 5])

# %% [markdown]
# ### Удаление пропусков (продолжение)

# %% [markdown]
# **Задание 11. Заполните пропуски в столбце `days_employed` медианными значениями по каждого типа занятости `income_type`.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['days_employed'].isna()), 'days_employed'] = \
    data.loc[(data['income_type'] == t), 'days_employed'].median()

# %% [markdown]
# **Задание 12. Убедитесь, что все пропуски заполнены. Проверьте себя и ещё раз выведите количество пропущенных значений для каждого столбца с помощью двух методов.**

# %%
data.isna().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# **Задание 13. Замените вещественный тип данных в столбце `total_income` на целочисленный с помощью метода `astype()`.**

# %%
data['total_income'] = data['total_income'].astype(int)

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# **Задание 14. Обработайте неявные дубликаты в столбце `education`. В этом столбце есть одни и те же значения, но записанные по-разному: с использованием заглавных и строчных букв. Приведите их к нижнему регистру. Проверьте остальные столбцы.**

# %%
data['education'] = data['education'].str.lower()

# %% [markdown]
# **Задание 15. Выведите на экран количество строк-дубликатов в данных. Если такие строки присутствуют, удалите их.**

# %%
data.duplicated().sum()
# Out:
# 71

# %%
data = data.drop_duplicates()

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# **Задание 16. На основании диапазонов, указанных ниже, создайте в датафрейме `data` столбец `total_income_category` с категориями:**
#
# - 0–30000 — `'E'`;
# - 30001–50000 — `'D'`;
# - 50001–200000 — `'C'`;
# - 200001–1000000 — `'B'`;
# - 1000001 и выше — `'A'`.
#
#
# **Например, кредитополучателю с доходом 25000 нужно назначить категорию `'E'`, а клиенту, получающему 235000, — `'B'`. Используйте собственную функцию с именем `categorize_income()` и метод `apply()`.**

# %%
def categorize_income(income):
    try:
        if 0 <= income <= 30000:
            return 'E'
        elif 30001 <= income <= 50000:
            return 'D'
        elif 50001 <= income <= 200000:
            return 'C'
        elif 200001 <= income <= 1000000:
            return 'B'
        elif income >= 1000001:
            return 'A'
    except:
        pass

# %%
data['total_income_category'] = data['total_income'].apply(categorize_income)

# %% [markdown]
# **Задание 17. Выведите на экран перечень уникальных целей взятия кредита из столбца `purpose`.**

# %%
data['purpose'].unique()
# Out:
# array(['покупка жилья', 'приобретение автомобиля',
#        'дополнительное образование', 'сыграть свадьбу',
#        'операции с жильем', 'образование', 'на проведение свадьбы',
#        'покупка жилья для семьи', 'покупка недвижимости',
#        'покупка коммерческой недвижимости', 'покупка жилой недвижимости',
#        'строительство собственной недвижимости', 'недвижимость',
#        'строительство недвижимости', 'на покупку подержанного автомобиля',
#        'на покупку своего автомобиля',
#        'операции с коммерческой недвижимостью',
#        'строительство жилой недвижимости', 'жилье',
#        'операции со своей недвижимостью', 'автомобили',
#        'заняться образованием', 'сделка с подержанным автомобилем',
#        'получение образования', 'автомобиль', 'свадьба',
#        'получение дополнительного образования', 'покупка своего жилья',
#        'операции с недвижимостью', 'получение высшего образования',
#        'свой автомобиль', 'сделка с автомобилем',
# ...

# %% [markdown]
# **Задание 18. Создайте функцию, которая на основании данных из столбца `purpose` сформирует новый столбец `purpose_category`, в который войдут следующие категории:**
#
# - `'операции с автомобилем'`,
# - `'операции с недвижимостью'`,
# - `'проведение свадьбы'`,
# - `'получение образования'`.
#
# **Например, если в столбце `purpose` находится подстрока `'на покупку автомобиля'`, то в столбце `purpose_category` должна появиться строка `'операции с автомобилем'`.**
#
# **Используйте собственную функцию с именем `categorize_purpose()` и метод `apply()`. Изучите данные в столбце `purpose` и определите, какие подстроки помогут вам правильно определить категорию.**

# %%
def categorize_purpose(row):
    try:
        if 'автом' in row:
            return 'операции с автомобилем'
        elif 'жил' in row or 'недвиж' in row:
            return 'операции с недвижимостью'
        elif 'свад' in row:
            return 'проведение свадьбы'
        elif 'образов' in row:
            return 'получение образования'
    except:
        return 'нет категории'

# %%
data['purpose_category'] = data['purpose'].apply(categorize_purpose)

# %% [markdown]
# ### Шаг 3. Исследуйте данные и ответьте на вопросы

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h4> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h4>
#
# В данном шаге четыре блока с похожим кодом, было здорово обернуть построение сводной и вывод ее в функцию для удобства.
#
# </div>

# %% [markdown]
# #### 3.1 Есть ли зависимость между количеством детей и возвратом кредита в срок?

# %%
# Ваш код будет здесь. Вы можете создавать новые ячейки.
data_debt = data[data['debt'] == 1] # имел долги
data_not_debt = data[data['debt'] == 0] # не имел долги

# %%
data_debt.shape
# Out:
# (1732, 14)

# %%
data_not_debt.shape
# Out:
# (19599, 14)

# %%
# 1732/(19599+1732)*100 #доля должников от общего числа клиентов

# %%
data_debt['children'].unique() 
# среди клиентов, которые имели долги - это семьи без детей или от 1 ребенка до 4 детей
# Out:
# array([0, 1, 2, 3, 4])

# %%
data_not_debt['children'].unique() 
# среди клиентов, которые не имели долги - это семьи без детей или от 1 ребенка до 5 детей
# Out:
# array([1, 0, 3, 2, 4, 5])

# %%
ser_data_debt = data_debt.groupby('children')['debt'].count() 
# такое распределение долгов в зависимости от кол-ва детей
ser_data_debt
# Out:
# children
# 0    1063
# 1     444
# 2     194
# 3      27
# 4       4
# Name: debt, dtype: int64

# %%
ser_data_not_debt = data_not_debt.groupby('children')['debt'].count() 
# такое распределение клиентов без долгов в зависимости от кол-ва детей
ser_data_not_debt
# Out:
# children
# 0    13028
# 1     4364
# 2     1858
# 3      303
# 4       37
# 5        9
# Name: debt, dtype: int64

# %%
# посчитаем долю несвоевременных возвратов по каждой категории (кол-ва детей)/Метрику назовем debt_of_children
debt_of_children = ser_data_debt / (ser_data_debt + ser_data_not_debt) * 100
debt_of_children = pd.DataFrame(debt_of_children).round(2).fillna('0')
# делаем табл, округляем, заполняем нулями и делаем индексы
debt_of_children['debt'] = debt_of_children['debt'].astype('float')
# изменим тип данных для сортировки
debt_of_children = debt_of_children.sort_values(by='debt')
# сортируем
debt_of_children = debt_of_children.rename(columns={'debt': 'debt_of_children_%'})
# переименуем колонку для более ясного восприятия
debt_of_children
# Out:
#           debt_of_children_%
# children
# 5                       0.00
# 0                       7.54
# 3                       8.18
# 1                       9.23
# 2                       9.45
# 4                       9.76

# %%
plt.figure(figsize=(10, 6))
debt_of_children['debt_of_children_%'].plot(kind='bar', color='brown')
plt.title('Долги в зависимости от детей в семье (%)')
plt.xlabel('Количество детей')
plt.ylabel('Доля должников (%)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# Решение после ревьеюра:

# %%
ch = data.pivot_table(index = ['children'], values='debt', aggfunc = ('mean', lambda X:
                                                                      X.count()))

def percent(x):
    return "{0:.2%}".format(x)

ch['mean'] = ch['mean'].apply(percent)
ch = ch.rename(columns={"<lambda_0>": "Количество записей", "mean": "Среднее"})
ch.sort_values(by='Количество записей', ascending=False)
# Out:
#           Количество записей Среднее
# children
# 0                    14091.0   7.54%
# 1                     4808.0   9.23%
# 2                     2052.0   9.45%
# 3                      330.0   8.18%
# 4                       41.0   9.76%
# 5                        9.0   0.00%

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h4>
#
# Спасибо за наглядную визуализацию, правильное применение метода `groupby()` и подсчет процента просроченных кредитов, это отличный шаг 👍.
# </div>

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h4> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h4>
#
# Выше у тебя [харкод](https://en.wikipedia.org/wiki/Hard_coding), то есть ты прописываешь руками числа, а не ссылаешься на значения из таблицы.
#
# Поясню, харкод, это когда ты подставляешь какие-то значения в код руками, а не вычисляешь методами из данных. В данном случае — это плохо, ведь если тебе дать аналогичные по структуре данные, то будут не верные построения и вычисления. Харкод не всегда плохо, например в играх получилось сделать прорыв в графике благодаря числу в коде, которое упрощает вычисления, можешь почитать в [статье](https://thecode.media/quake-root/).
#
# </div>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h4> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h4>
#
# Вижу очень скрупулезный подход к решению задачи, однако ответить на вопрос можно одной - двумя строчками кода, добавив к методу `groupby()` функцию [`agg()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.agg.html) (о ней упоминалось в разделе «Работа с пропусками в категориальных переменных»), позволяющую применить несколько агрегаций.
#
# Как итог должна получиться единая сводная таблица, содержащая в себе:
# - название категории;
# - количество клиентов в категории;
# - количество просрочивших кредит или выплативших вовремя;
# - процент или доля просрочивших кредит или выплативших вовремя.
#
#
# **Построй, пожалуйста, единую сводную таблицу здесь и в последующих шагах 3.2-3.4.**
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Действительно debt воспринимаем не как количественную переменную, а как категорию и тогда нам не обзяательно делить таблицу на деложников и нет
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green"> v2 Комментарий ревьюера (зеленый)</font></h4>
#
# Спасибо за компактное использование `pivot_table`, применение функции `percent` и переименование столбцов. Таблицу приятно читать.
#
# Ниже представил более лаконичное решение на основе твоего кода.
#
# </div>

# %%
# Код ревьюера

# Создание сводной таблицы с подсчетами
ch = data.pivot_table(index='children', values='debt', aggfunc=['count', 'sum', 'mean'])

# Переименуем колонки для удобства
ch.columns = ['Количество заемщиков', 'Количество должников', 'Процент просрочивших кредит']

# Сортируем таблицу по 'Процент просрочивших кредит' и форматируем его как проценты
ch = ch.sort_values(by='Количество заемщиков', ascending=False)
ch['Процент просрочивших кредит'] = ch['Процент просрочивших кредит'].apply(lambda x: "{:.2%}".format(x))

ch
# Out:
#           Количество заемщиков  Количество должников  \
# children
# 0                        14091                  1063
# 1                         4808                   444
# 2                         2052                   194
# 3                          330                    27
# 4                           41                     4
# 5                            9                     0
#
#          Процент просрочивших кредит
# children
# 0                              7.54%
# 1                              9.23%
# 2                              9.45%
# 3                              8.18%
# 4                              9.76%
# 5                              0.00%

# %% [markdown]
# **Вывод:**
# Принимая во внимание, что мы говорим о проценте должников среди всех клиентов такой категории, то отметить следующее:
#
# * семьи с 5-ю детьми не имели долгов (но их доля в нашем наблюдении сильно мала и на ее основании делать выводы поспешно),
# * семьи с 4-мя детьми оказались самыми частыми должниками (хотя их доля также ничтожно мала и делать выводы на основании наших налюдений преждевременно),
# * семьи с 3 более "надежные", чем семьи с 2-мя детьми.
# * Прямой связи между количеством детей в семье и фактом наличия долга не усматривается по анализируемым данным.
# * При этом, мы можем утверждать, что семьи без детей имеют меньше проблем с долгами, чем семьи с детьми!

# %% [markdown]
# После ревью:
# * 8.12% клиентов допускают просрочки по выплате кредитов.
# * Клиенты без детей чаще других выплачивают кредит в срок (7.54% должники).
# * Клиенты, у которых 3+ детей реже допускают просрочку, чем немногодетные семьи.
# * Клиенты с 1 или 2 детьми чаще всего не выплачивали кредит в срок (9.23% и 9.45% должники соответственно).

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h4> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h4>
#
# Верно подмечена общая тенденция и то, что некоторые категории слишком малы, чтобы по ним делать выводы. Если объединить категорию с 3, 4, 5 детьми в категорию «3+», можно получить сбалансированные выборки и работать со всеми данными.
#
# Вывод — это важный этап нашей работы, а для заказчика ценны цифры. **Пожалуйста, добавь ключевые цифры здесь и в последующих выводах.**
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍  У заёмщиков без детей меньше вероятность просрочки.
#
# </div>

# %% [markdown]
# #### 3.2 Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
# Ваш код будет здесь. Вы можете создавать новые ячейки.
data_debt['family_status'].unique()
# Смотрим какие виды семейного положения имеются в наших данных
# Out:
# array(['гражданский брак', 'Не женат / не замужем', 'женат / замужем',
#        'вдовец / вдова', 'в разводе'], dtype=object)

# %%
# разделим данные на группы: должник или не должник, хотя в нашем случае мы сделали выше, поэтом закомментирую это
# data_debt = data[data['debt'] == 1] # имел долги
# data_not_debt = data[data['debt'] == 0] # не имел долги
ser_family_status_debt = data_debt.groupby('family_status')['debt'].count()  
ser_family_status_debt # должники
# Out:
# family_status
# Не женат / не замужем    273
# в разводе                 84
# вдовец / вдова            63
# гражданский брак         385
# женат / замужем          927
# Name: debt, dtype: int64

# %%
ser_family_status_not_debt = data_not_debt.groupby('family_status')['debt'].count()
ser_family_status_not_debt # не должники
# Out:
# family_status
# Не женат / не замужем     2523
# в разводе                 1105
# вдовец / вдова             888
# гражданский брак          3749
# женат / замужем          11334
# Name: debt, dtype: int64

# %%
# посчитаем долю несвоевременных возвратов по каждой категории (семейный статус)/Метрику назовем debt_of_family_st
debt_of_family_st = ser_family_status_debt / (ser_family_status_debt + ser_family_status_not_debt) * 100
debt_of_family_st = pd.DataFrame(debt_of_family_st).round(2).fillna('0')
# делаем табл, округляем, заполняем нулями и делаем индексы
debt_of_family_st['debt'] = debt_of_family_st['debt'].astype('float')
# изменим тип данных для сортировки
debt_of_family_st = debt_of_family_st.sort_values(by='debt')
# сортируем
debt_of_family_st = debt_of_family_st.rename(columns={'debt': 'debt_of_family_status_%'})
# переименуем колонку для более ясного восприятия
debt_of_family_st
# Out:
#                        debt_of_family_status_%
# family_status
# вдовец / вдова                            6.62
# в разводе                                 7.06
# женат / замужем                           7.56
# гражданский брак                          9.31
# Не женат / не замужем                     9.76

# %%
plt.figure(figsize=(10, 6))
debt_of_family_st['debt_of_family_status_%'].plot(kind='bar', color='lightblue')
plt.title('Долги в зависимости от семейного положения (%)')
plt.ylabel('Доля должников (%)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод:**
# Тут уже у нас вырисовывается некий тренд жизненного пути. Больше всего должников мы наблюдаем в категории "не женатых", чуть меньше клиентов, которые относятся к категории "гражданский брак", еще меньше случаем долгов в категории "женатых" и еще меньше у тех кто "в разводе" и "вдовец".
#
# **Таким образом, не женатые клиенты имеют повышенный риск не возвратить кредит вовремя, а клиенты, кторые находятся или находились в браке более надежные**

# %% [markdown]
# ***После ревью:***

# %%
fs = data.pivot_table(index = ['family_status'], values='debt', aggfunc = ('mean', lambda X:
                                                                      X.count()))

fs['mean'] = fs['mean'].apply(percent)
fs = fs.rename(columns={"<lambda_0>": "Количество записей", "mean": "Среднее"})
fs.sort_values(by='Количество записей', ascending=False)
# Out:
#                        Количество записей Среднее
# family_status
# женат / замужем                   12261.0   7.56%
# гражданский брак                   4134.0   9.31%
# Не женат / не замужем              2796.0   9.76%
# в разводе                          1189.0   7.06%
# вдовец / вдова                      951.0   6.62%

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h4> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h4>
#
# При формулировании зависимости можно сравнить заемщиков, которые были или находятся в официальном браке, с остальными.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# Верно подмечено, что заемщики, которые состоят или состояли в браке, реже допускают просрочки.
#
# </div>

# %% [markdown]
# #### 3.3 Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
# Ваш код будет здесь. Вы можете создавать новые ячейки.
# разделим данные на группы: должник или не должник, хотя в нашем случае мы сделали выше, поэтом закомментирую это
# data_debt = data[data['debt'] == 1] # имел долги
# data_not_debt = data[data['debt'] == 0] # не имел долги
data_debt['total_income'].describe() # глянем статистику по доходу должника
# Out:
# count    1.732000e+03
# mean     1.611523e+05
# std      9.792373e+04
# min      2.066700e+04
# 25%      1.081488e+05
# 50%      1.425940e+05
# 75%      1.875995e+05
# max      2.200852e+06
# Name: total_income, dtype: float64

# %%
data_not_debt['total_income'].describe() # глянем статистику по доходу не должника
# Out:
# count    1.959900e+04
# mean     1.657131e+05
# std      9.834230e+04
# min      2.120500e+04
# 25%      1.074405e+05
# 50%      1.425940e+05
# 75%      1.966145e+05
# max      2.265604e+06
# Name: total_income, dtype: float64

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h4> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h4>
#
# Отлично, что ты начал с анализа статистики по доходу для должников и недолжников!
#
# Такой обзор даёт общее представление, но для более детального ответа на вопрос о зависимости лучше воспользоваваться функцией [pivot_table](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) или [groupby](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html), о них упоминалось в спринте «Предобработка данных», теме «Работа с пропусками», уроках «Вы обнаружили NaN и None» и «Работа с пропусками в категориальных переменных».
#
# **Учитывай, пожалуйста, что для  выявления зависимостей стоит сравнивать самые большие, сопоставимые по размеру выборки.**
#
# </div>

# %% [markdown]
# После ревью:
# Ранее мы сделали разделение на категории по уровня дохода клиентов:
# * 0–30 000 — 'E';
# * 30 001–50 000 — 'D';
# * 50 001–200 000 — 'C';
# * 200 001–1 000 000 — 'B';
# * 1 000 001 и выше — 'A'.

# %%
profit_client = data.pivot_table(index = ['total_income_category'], values='debt', aggfunc = ('mean', lambda X:
                                                                      X.count()))

profit_client['mean'] = profit_client['mean'].apply(percent)
profit_client = profit_client.rename(columns={"<lambda_0>": "Количество записей", "mean": "Средняя задолженость"})
profit_client.sort_values(by='Количество записей', ascending=False)
# Out:
#                        Количество записей Средняя задолженость
# total_income_category
# C                                 15921.0                8.50%
# B                                  5014.0                7.06%
# D                                   349.0                6.02%
# A                                    25.0                8.00%
# E                                    22.0                9.09%

# %% [markdown]
# **Вывод:**
# На основании данных по должникам и не должникам с помощью метода .describe() мы наблюдаем следующее:
# * средний доход у должников оказался ниже, чем у тех, кто долгов не имел
# * средний доход у половины клиентов среди должников и не должников оказался одинаковым!
# * а у 25% должников доход был выше, чем у тех, кто не имел долгов

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h4> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h4>
#
# После того как будет составлена сводная таблица, ожидаю получить ответ на вопрос о том, как доход влияет на своевременный возврат кредита.
#
# </div>

# %% [markdown]
# **Вывод после ревью**
#
# * Самые богатые (доход более 1 млн) и самые бедные клиенты (доход не более 30 тыс.) относительно часто не возвращают кредит в срок (8.00% и 9.09% соответственно)
#
# * Категория С не оплачивает кредит вовремя в 8.50% случаев
#
# * Клиенты с не самым высоким доходом. Например клиенты категории В не оплачивают кредит вовремя в 7.06% случаев
#
# * Категория D, невовремя оплачивает кредиты в 6.02% случаев
#
# **Таким образом, самые надежные клиенты имеют доход немного выше среднего (200 001–1 000 000) или средний (50 001–200 000)**

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h4> ⚠️ <font color="DarkGoldenRod"> v2 Комментарий ревьюера (желтый)</font></h4>
#
# Спасибо за интересные наблюдения, по группам А, D, E крайне мало данных, чтобы, опираться на них.
# Если, формулировать зависимость для основных категорий B и C, то заемщики с более высоким уровнем дохода реже допускают просрочку.
#
# </div>

# %% [markdown]
# #### 3.4 Как разные цели кредита влияют на его возврат в срок?

# %%
# Ваш код будет здесь. Вы можете создавать новые ячейки.
data['purpose_category'].unique()
# Out:
# array(['операции с недвижимостью', 'операции с автомобилем',
#        'получение образования', 'проведение свадьбы'], dtype=object)

# %%
# разделим данные на группы: должник или не должник, хотя в нашем случае мы сделали выше, поэтом закомментирую это
# data_debt = data[data['debt'] == 1] # имел долги
# data_not_debt = data[data['debt'] == 0] # не имел долги
ser_category_debt = data_debt.groupby('purpose_category')['debt'].count()  
ser_category_debt # должники
# Out:
# purpose_category
# операции с автомобилем      400
# операции с недвижимостью    780
# получение образования       369
# проведение свадьбы          183
# Name: debt, dtype: int64

# %%
ser_category_not_debt = data_not_debt.groupby('purpose_category')['debt'].count()  
ser_category_not_debt # не должники
# Out:
# purpose_category
# операции с автомобилем      3879
# операции с недвижимостью    9971
# получение образования       3619
# проведение свадьбы          2130
# Name: debt, dtype: int64

# %%
# посчитаем долю несвоевременных возвратов по каждой категории (цель кредита)/Метрику назовем debt_of_category
debt_of_category = ser_category_debt / (ser_category_debt + ser_category_not_debt) * 100
debt_of_category = pd.DataFrame(debt_of_category).round(2).fillna('0')
# делаем табл, округляем, заполняем нулями и делаем индексы
debt_of_category['debt'] = debt_of_category['debt'].astype('float')
# изменим тип данных для сортировки
debt_of_category = debt_of_category.sort_values(by='debt')
# сортируем
debt_of_category = debt_of_category.rename(columns={'debt': 'debt_of_category'})
# переименуем колонку для более ясного восприятия
debt_of_category
# Out:
#                           debt_of_category
# purpose_category
# операции с недвижимостью              7.26
# проведение свадьбы                    7.91
# получение образования                 9.25
# операции с автомобилем                9.35

# %%
plt.figure(figsize=(10, 6))
debt_of_category['debt_of_category'].plot(kind='bar', color='blue')
plt.title('Долги в зависимости от цели кредита (%)')
plt.ylabel('Доля должников (%)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод:**
#
# Не удивительно, но меньше всего должников у приобретателей недвижимости, чуть больше должников среди тех, кто проводил свадьбу. Сильно больше должников среди тех, кто брал кредит получение образования и самая большая доля должников находится в категории тех, кто покупал автомобиль в кредит

# %% [markdown]
# ***После ревью:***

# %%
p_с = data.pivot_table(index = ['purpose_category'], values='debt', aggfunc = ('mean', lambda X:
                                                                      X.count()))

p_с['mean'] = p_с['mean'].apply(percent)
p_с = p_с.rename(columns={"<lambda_0>": "Количество записей", "mean": "Средняя задолженость"})
p_с.sort_values(by='Количество записей', ascending=False)
# Out:
#                           Количество записей Средняя задолженость
# purpose_category
# операции с недвижимостью             10751.0                7.26%
# операции с автомобилем                4279.0                9.35%
# получение образования                 3988.0                9.25%
# проведение свадьбы                    2313.0                7.91%

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h4>
#
# Да, категории с наибольшей долей задолженности — операции с автомобилем и образование (по 9%), в то время как недвижимость и свадьба возвращаются более своевременно (7.3% и 7.9%).
#
# </div>

# %% [markdown]
# #### 3.5 Приведите возможные причины появления пропусков в исходных данных.

# %% [markdown]
# *Ответ:* Возможно часть клиентов с пропусками (это около 10%) работают не официально как это часто бывает и не могли подтвердить свой стаж работы и доход по основному месту работы либо это техническая ошибка и часть данных просто не перенеслась из какой-то системы

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h4>
#
# Да, основные причины — технические ошибки и человеческий фактор.
#
# </div>

# %% [markdown]
# #### 3.6 Объясните, почему заполнить пропуски медианным значением — лучшее решение для количественных переменных.

# %% [markdown]
# *Ответ:*
# Медианное значение меньше исказит действительность, чем средние значения т.к. среднее арифметическое при своем расчете включает и самые большие значения и самы маленькие и если этот разбро сильно велик, а каличество таких экстремальных случае невелико6 то использование среднего арифметического сильно поменяет картину происходящего потому что большинство остальных данных будет сильно отличаться от этого среднего значения. А если использовать медианное значение, которое равняется такому значению, которое есть в 50% строк наших данных, то и искажение этих значений снизится потому что его подсчете не будут включаться супербольшие данные, которые при подсчете сред. арифметического нам искажали данные

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Верно, медиана, в отличие от среднего значения, менее чувствительна к выбросам, среднее значение смещается в сторону выбросов.
#
# </div>

# %% [markdown]
# ### Шаг 4: общий вывод.

# %% [markdown]
# Напишите ваш общий вывод.

# %% [markdown]
# Самый надежный клиент это:
# * кто берет кредит на операции с недвижимостью
# * вдовец/вдова
# * не имеет детей

# %% [markdown]
# Высокий риск для банка, если клиент:
# * кредитуется для покупки авто или получения образования
# * не женат
# * имеет детей

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# В общем выводе хочется тезисно видеть все промежуточные выводы с цифрами. Это очень важно, поскольку топ-менеджеры, в большинстве своем, смотрят сразу сюда и только сюда...
#
# Тут важно обратиться к целям, которые были озвучены в самом начале и ответить на все вопросы. Важно оформить все тезисно и с цифрами. Еще важно описать все промежуточные выводы, которых не прописано в целях.
# Вкратце структура такая:
# - как были предобработаны данные(тут важно написать про изменения, если заполнялись пропуски или преобразовывались строки)
# - пройдись по целям и ответь на вопросы
# - добавь промежуточные выводы, которые считаешь нужным отметить
#
# Еще очень важно помнить, для кого ты делаешь проект, в зависимости от этого нужно сделать определенные акценты. В данном случае проект учебный, поэтому нужно ориентироваться по описанию.
#
# Для красивого оформления можешь воспользоваться [Кратким руководством по Маркдауну](https://paulradzkov.com/2014/markdown_cheatsheet/).
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Валентин, а как быть с моими старыми ячейками? Сейчас я их как бы переделал и они в общем больше и не нужны, но я их не удалил на всякий случай
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green"> v2 Комментарий ревьюера (зеленый)</font></h4>
#
# Дальше ты будеешь собирать портфолио, чтобы использовать его при поиске работы. В это портфолио следует включать только финальные версии проектов, без комментариев от ревьюеров. В процессе подготовки проекта к портфолио ты можешь убрать все лишнее.
#
# </div>

# %% [markdown]
# В процессе предобработки данных мы наблюдали отсутствие некоторых значений в части дохода и стажа работы у некоторых клиентов. Недостающие данные мы заполнили медианным значением, чтобы при анализе получить более точны значения. Полагаем, что указанные данные отсутствовали либо из-за технической ошибки либо из-за человечкого фактора (клиенты не имели официального трудоустройства и не могли документально подтвердить свой доход и стаж).
#
# После заполнения отсутствующих значений, для ранжирования клиентов мы разделили их на группы в зависимости от доходов, семейного положения и количества детей, а также цели кредитования.
# По резульатам данной предобработки мы оценили как влияют вышеуказанные критерии на возврат займов и заметили следующее.
#
# 8.12% клиентов допускают просрочки по выплате кредитов.
#
# После проведенного анализа мы можем дать портрет надежному клиенту в плане своевременного возрата кредита, а также описать некоторые признаки не надежного клиента:
#
# * children - портретом идеального клиента является семья без детей. Худшим клиентом является семья у которой 1-2 ребенка.
#
#
# * family_status - портретом идеального клиента является женатый и даже бывший в браке клиент. Худшим клиентом является не женатый.
#
#
# * total_income - портретом идеального клиента является клиент c доходом немного выше среднего (200 001–1 000 000) или средним (50 001–200 000). Худшим клиентом является: самые бедные (доход не более 30 тыс.) или самые богатые клиенты (доход более 1 млн).
#
#
# * purpose - портретом идеального клиента является цель кредитования для покупки недвижимости. Худшей целью для банка является кредитование для приобретения автомобиля.

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Дополнил.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">v2 Комментарий ревьюера (красный)</font></h5>
#
# Да, спасибо за красивое оформление исследовательского этапа, однако попрошу тебя добавить в вывод не менее важный этап предобработки данных.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green"> v3 Комментарий ревьюера (зеленый)</font></h4>
#
# Спасибо,хороший вывод, который содержит все промежуточные результаты 🔥.
#
# </div>
