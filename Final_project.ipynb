# %% [markdown]
# <div class="well">
# <font color='blue' size=5><b>Комментарий ментора</b></font>
#
# <font color='blue'>Здравствуй, Алексей! Это Демин Вячеслав. Мы делаем очень классный проект, давайте смотреть, что получилось.
# <br> Если ты не против, давай перейдем на "ты". Согласен?
#
# <font color='blue'>Я буду использовать различные цвета и знаки, чтобы было удобнее воспринимать мои комментарии:</font>
#
#
# ---
#
# <div class="well">
# <font color='blue'>Синий текст - просто текст комментария</font>
# </div>
# <div class="alert alert-success">
# <font color='green'> ✔️Зеленый текст - все отлично</font>
# </div>
# <div class="alert alert-warning">
# <font color='darkorange'>⚠️Оранжевый текст - есть рекомендации, на что стоит обратить внимание</font>
# </div>
# <div class="alert alert-danger">
# <font color='crimson'> ❌Красный текст - есть недочеты</font>
# </div>
# ---
#
# <font color='blue'><b>Прошу не удалять и перемещать мои комментарии, каждый следующий проект должен включать предыдущий со всем комментариями.</b></font>
#
# <font color='blue'>Твои комментарии можно помечать так:<div class="alert alert-info"> <b>Комментарий студента: ...</b></font>
# </div>

# %% [markdown]
# <div class='well'>
# <font color='blue' size=5><b>Комментарий ментора V2</b></font>
# <font color='blue'><br>Новые комментарии буду вести с меткой V2.
# <br> Спасибо, что учел замечания, я буду оставлять новые комментарии ниже старых. Старые выполненные буду зачеркивать <strike>так</strike>.</font>

# %% [markdown]
# <div class='well'>
# <font color='blue' size=5><b>Комментарий ментора V3</b></font>
# <font color='blue'><br> Посмотрим, что получилось

# %% [markdown]
# <div class='well'>
# <font color='blue' size=5><b>Комментарий ментора V4</b></font>
# <font color='blue'><br> С каждым шагом мы приближаемся к лучшей модели

# %% [markdown]
# <div class="well">
# <font color='blue' size=5><b>Комментарий ментора v5</b></font>
#
# <font color='blue'>Здравствуй, Алексей! Это Демин Вячеслав.
#
# <font color='blue'>Я буду использовать различные цвета и знаки, чтобы было удобнее воспринимать мои комментарии:</font>
#
#
# ---
#
# <div class="well">
# <font color='blue'>Синий текст - просто текст комментария</font>
# </div>
# <div class="alert alert-success">
# <font color='green'> ✔️Зеленый текст - все отлично</font>
# </div>
# <div class="alert alert-warning">
# <font color='darkorange'>⚠️Оранжевый текст - есть рекомендации, на что стоит обратить внимание</font>
# </div>
# <div class="alert alert-danger">
# <font color='crimson'> ❌Красный текст - есть недочеты</font>
# </div>
# ---
#
# <font color='blue'><b>Прошу не удалять и перемещать мои комментарии, каждый следующий проект должен включать предыдущий со всем комментариями.</b></font>
#
# <font color='blue'>Твои комментарии можно помечать так:<div class="alert alert-info"> <b>Комментарий студента: ...</b></font>
# </div>

# %% [markdown]
# <div class='well'>
# <font color='blue' size=5><b>Комментарий ментора V6</b></font>
# <font color='blue'><br> Посмотрим, что в итоге у тебя получилось по проекту
#
# <br> Я прошелся по коду твоего проекта и отмечу, где корректировал его, чтобы показать, как работает бустинг

# %% [markdown]
# #  Промышленность

# %% [markdown]
# <div class="alert alert-danger">
# <font color='blue'><b>Комментарий ментора v5</b></font>
# <br><font color='crimson'> ❌ К сожалению использование RS как гипер параметра нельзя, так как он зафиксирован в этой задаче. Буду проверять работу с установленным RS. Тест не проходит. Попробуй тогда добавить признаки:
# <br>- Суммарные присадки bulk
# <br>- Суммарные провод wire
# <br>Из нагрева используй все для бустинга или оставь только full_power и heating_time или full_energy
# <br> Попробуй добавить предпоследнюю температуру или среднюю температуру промежуточных замеров температуры. Ты будь внимателен, так как надо исключить таргет из расчета признака
# <br><font color='crimson'> ❌ Нужно вернуть все комментрии, которые я оставлял по предыдущим этапам

# %% [markdown]
# Чтобы оптимизировать производственные расходы, металлургический комбинат «Стальная птица» решил уменьшить потребление электроэнергии на этапе обработки стали. Для этого комбинату нужно контролировать температуру сплава. Ваша задача — построить модель, которая будет её предсказывать.
#
# Заказчик хочет использовать разработанную модель для имитации технологического процесса. Ниже расскажем о деталях этого процесса. Их важно знать, прежде чем генерировать новые признаки.
# Описание этапа обработки
#
# Сталь обрабатывают в металлическом ковше вместимостью около 100 тонн. Чтобы ковш выдерживал высокие температуры, изнутри его облицовывают огнеупорным кирпичом. Расплавленную сталь заливают в ковш и подогревают до нужной температуры графитовыми электродами. Они установлены в крышке ковша.
#
# Из сплава выводится сера (этот процесс — десульфурация), добавлением примесей корректируется химический состав и отбираются пробы. Сталь легируют — изменяют её состав — подавая куски сплава из бункера для сыпучих материалов или проволоку через специальный трайб-аппарат (от англ. tribe — «масса»).
#
# Перед тем как первый раз ввести легирующие добавки, измеряют температуру стали и производят её химический анализ. Потом температуру на несколько минут повышают, добавляют легирующие материалы и продувают сплав инертным газом. Затем его перемешивают и снова проводят измерения. Такой цикл повторяется до достижения целевого химического состава и оптимальной температуры плавки.
#
# Тогда расплавленная сталь отправляется на доводку металла или поступает в машину непрерывной разливки. Оттуда готовый продукт выходит в виде заготовок-слябов (от англ. slab — «плита»).

# %% [markdown]
# # Описание данных
#
# Данные состоят из нескольких файлов, полученных из разных источников:
# * data_arc_new.csv — данные об электродах;
# * data_bulk_new.csv — данные о подаче сыпучих материалов (объём);
# * data_bulk_time_new.csv — данные о подаче сыпучих материалов (время);
# * data_gas_new.csv — данные о продувке сплава газом;
# * data_temp_new.csv — результаты измерения температуры;
# * data_wire_new.csv — данные о проволочных материалах (объём);
# * data_wire_time_new.csv — данные о проволочных материалах (время).
#
# #### Файл data_arc_new.csv
# * key — номер партии;
# * Начало нагрева дугой — время начала нагрева;
# * Конец нагрева дугой — время окончания нагрева;
# * Активная мощность — значение активной мощности;
# * Реактивная мощность — значение реактивной мощности.
#
# #### Файл data_bulk_new.csv
# * key — номер партии;
# * Bulk 1 … Bulk 15 — объём подаваемого материала.
#
# #### Файл data_bulk_time_new.csv
# * key — номер партии;
# * Bulk 1 … Bulk 15 — время подачи материала.
#
# #### Файл data_gas_new.csv
# * key — номер партии;
# * Газ 1 — объём подаваемого газа.
#
# #### Файл data_temp_new.csv
# * key — номер партии;
# * Время замера — время замера;
# * Температура — значение температуры.
#
# #### Файл data_wire_new.csv
# * key — номер партии;
# * Wire 1 … Wire 9 — объём подаваемых проволочных материалов.
#
# ### Файл data_wire_time_new.csv
# * key — номер партии;
# * Wire 1 … Wire 9 — время подачи проволочных материалов.
# _______

# %% [markdown]
# ### План работы
#
# #### Шаг 1. Загрузка данных
# Загрузите данные и выполните их первичный осмотр.
#
# #### Шаг 2. Исследовательский анализ и предобработка данных
# Выполните исследовательский анализ каждого датафрейма и при необходимости выполните предобработку. Сделайте выводы об имеющихся признаках: понадобятся ли они для обучения моделей.
#
# ##### Шаг 3. Объединение данных
# Объедините выбранные вами признаки в один датафрейм по ключу.
#
# #### Шаг 4. Исследовательский анализ и предобработка данных объединённого датафрейма
# Выполните исследовательский анализ объединённого датафрейма, визуализируйте распределения признаков и при необходимости выполните предобработку. Проведите корреляционный анализ.
#
# #### Шаг 5. Подготовка данных
# Выполните подготовку данных для обучения модели. Разделите данные на две выборки, при масштабировании и кодировании учитывайте особенности данных и моделей.
#
# ##### Шаг 6. Обучение моделей машинного обучения
# Обучите как минимум две модели. Хотя бы для одной из них подберите как минимум два гиперпараметра.
#
# ##### Шаг 7. Выбор лучшей модели
# Выберите лучшую модель и проверьте её качество на тестовой выборке.
#
# ##### Шаг 8. Общий вывод и рекомендации заказчику
# Сделайте общий вывод о проделанной работе: опишите основные этапы работы, полученные результаты и дайте рекомендации для бизнеса.
# ______
#
# ##### Уточнения заказчика
# * MAE = 6.8
# * Правильная партия температуры -2
# ________

# %% [markdown]
# <div class="alert alert-success">
# <font color='blue'><b>Комментарий ментора</b></font><br>
# <font color='green'> ✔️ Хорошее описание и есть понимание, что за данные</font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

import math

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, PowerTransformer
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score, RepeatedKFold
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import KFold

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor

from sklearn.feature_selection import SelectKBest, f_regression

from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor

# Визуализация пропусков
try:
    import missingno as msno
except ImportError:
    # !pip install missingno -q
    import missingno as msno

warnings.filterwarnings('ignore', category=DeprecationWarning)
pd.set_option('display.max_columns', None)

# Фиксация random state
RANDOM_STATE = 160625

# %%
def file_download(file_name):
    try:
        data = pd.read_csv(f'{file_name}')
    except:
        data = pd.read_csv(f'https://code.s3.yandex.net/datasets/{file_name}')
    return data

# %% [markdown]
# #### Шаг 1. Загрузка данных
# Загрузите данные и выполните их первичный осмотр.

# %%
#данные об электродах
data_arc = file_download('data_arc_new.csv')
display(data_arc.shape)
data_arc.head(5)
# Out:
# (14876, 5)
#    key Начало нагрева дугой  Конец нагрева дугой  Активная мощность  \
# 0    1  2019-05-03 11:02:14  2019-05-03 11:06:02           0.305130
# 1    1  2019-05-03 11:07:28  2019-05-03 11:10:33           0.765658
# 2    1  2019-05-03 11:11:44  2019-05-03 11:14:36           0.580313
# 3    1  2019-05-03 11:18:14  2019-05-03 11:24:19           0.518496
# 4    1  2019-05-03 11:26:09  2019-05-03 11:28:37           0.867133
#
#    Реактивная мощность
# 0             0.211253
# 1             0.477438
# 2             0.430460
# 3             0.379979
# 4             0.643691

# %%
#данные о подаче сыпучих материалов (объём)
data_bulk = file_download('data_bulk_new.csv')
display(data_bulk.shape)
data_bulk.head(5)
# Out:
# (3129, 16)
#    key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# 0    1     NaN     NaN     NaN    43.0     NaN     NaN     NaN     NaN
# 1    2     NaN     NaN     NaN    73.0     NaN     NaN     NaN     NaN
# 2    3     NaN     NaN     NaN    34.0     NaN     NaN     NaN     NaN
# 3    4     NaN     NaN     NaN    81.0     NaN     NaN     NaN     NaN
# 4    5     NaN     NaN     NaN    78.0     NaN     NaN     NaN     NaN
#
#    Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 0     NaN      NaN      NaN    206.0      NaN    150.0    154.0
# 1     NaN      NaN      NaN    206.0      NaN    149.0    154.0
# 2     NaN      NaN      NaN    205.0      NaN    152.0    153.0
# 3     NaN      NaN      NaN    207.0      NaN    153.0    154.0
# 4     NaN      NaN      NaN    203.0      NaN    151.0    152.0

# %%
#данные о подаче сыпучих материалов (время)
data_bulk_time = file_download('data_bulk_time_new.csv')
display(data_bulk_time.shape)
data_bulk_time.head(5)
# Out:
# (3129, 16)
#    key Bulk 1 Bulk 2 Bulk 3               Bulk 4 Bulk 5 Bulk 6 Bulk 7 Bulk 8  \
# 0    1    NaN    NaN    NaN  2019-05-03 11:28:48    NaN    NaN    NaN    NaN
# 1    2    NaN    NaN    NaN  2019-05-03 11:36:50    NaN    NaN    NaN    NaN
# 2    3    NaN    NaN    NaN  2019-05-03 12:32:39    NaN    NaN    NaN    NaN
# 3    4    NaN    NaN    NaN  2019-05-03 12:43:22    NaN    NaN    NaN    NaN
# 4    5    NaN    NaN    NaN  2019-05-03 13:30:47    NaN    NaN    NaN    NaN
#
#   Bulk 9 Bulk 10 Bulk 11              Bulk 12 Bulk 13              Bulk 14  \
# 0    NaN     NaN     NaN  2019-05-03 11:24:31     NaN  2019-05-03 11:14:50
# 1    NaN     NaN     NaN  2019-05-03 11:53:30     NaN  2019-05-03 11:48:37
# 2    NaN     NaN     NaN  2019-05-03 12:27:13     NaN  2019-05-03 12:21:01
# 3    NaN     NaN     NaN  2019-05-03 12:58:00     NaN  2019-05-03 12:51:11
# 4    NaN     NaN     NaN  2019-05-03 13:30:47     NaN  2019-05-03 13:34:12
#
#                Bulk 15
# ...

# %%
#данные о продувке сплава газом
data_gas = file_download('data_gas_new.csv')
display(data_gas.shape)
data_gas.head(5)
# Out:
# (3239, 2)
#    key      Газ 1
# 0    1  29.749986
# 1    2  12.555561
# 2    3  28.554793
# 3    4  18.841219
# 4    5   5.413692

# %%
#результаты измерения температуры
data_temp = file_download('data_temp_new.csv')
display(data_temp.shape)
data_temp.head(5)
# Out:
# (18092, 3)
#    key         Время замера  Температура
# 0    1  2019-05-03 11:02:04       1571.0
# 1    1  2019-05-03 11:07:18       1604.0
# 2    1  2019-05-03 11:11:34       1618.0
# 3    1  2019-05-03 11:18:04       1601.0
# 4    1  2019-05-03 11:25:59       1606.0

# %%
#данные о проволочных материалах (объём)
data_wire = file_download('data_wire_new.csv')
display(data_wire.shape)
data_wire.head(5)
# Out:
# (3081, 10)
#    key     Wire 1   Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  \
# 0    1  60.059998      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2  96.052315      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    3  91.160157      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3    4  89.063515      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4    5  89.238236  9.11456     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Wire 9
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
#данные о проволочных материалах (время)
data_wire_time = file_download('data_wire_time_new.csv')
display(data_wire_time.shape)
data_wire_time.head(5)
# Out:
# (3081, 10)
#    key               Wire 1               Wire 2 Wire 3 Wire 4 Wire 5 Wire 6  \
# 0    1  2019-05-03 11:06:19                  NaN    NaN    NaN    NaN    NaN
# 1    2  2019-05-03 11:36:50                  NaN    NaN    NaN    NaN    NaN
# 2    3  2019-05-03 12:11:46                  NaN    NaN    NaN    NaN    NaN
# 3    4  2019-05-03 12:43:22                  NaN    NaN    NaN    NaN    NaN
# 4    5  2019-05-03 13:20:44  2019-05-03 13:15:34    NaN    NaN    NaN    NaN
#
#   Wire 7 Wire 8 Wire 9
# 0    NaN    NaN    NaN
# 1    NaN    NaN    NaN
# 2    NaN    NaN    NaN
# 3    NaN    NaN    NaN
# 4    NaN    NaN    NaN

# %% [markdown]
# Вывод по загрузке данных:
# * Загружено 7 датасетов предоставленных заказчиком
# * Загруженные данные соответствуют описанию
# * Размерности датасетов отличаются друг от друга и требуют исследовательского анализа

# %% [markdown]
# #### Шаг 2. Исследовательский анализ и предобработка данных
# Выполните исследовательский анализ каждого датафрейма и при необходимости выполните предобработку. Сделайте выводы об имеющихся признаках: понадобятся ли они для обучения моделей.

# %%
def res_analysis(data):
    display(data.info())
    display(data.loc[:, ~data.columns.isin(['key'])].describe().round(2))
    display('Количество явных дубликатов:', data.duplicated().sum())
    display('Доля пропушенных значений:', data.isna().sum() / data.shape[0] * 100.00)
    display('Диаграмма ненулевых значений:')
    msno.bar(data, figsize=(8, 3), fontsize=8)

# %%
def hist_plot(df, figsize):
    count_list = df.loc[:, ~df.columns.isin(['key'])].select_dtypes(include='number').columns.tolist()
    row = math.ceil(len(count_list))
    fig, axes = plt.subplots(row, 2, figsize=(12, figsize))
    plt.suptitle('Распределение по количественным признакам',
                 x=0.5,
                 y=0.9,
                 fontsize=12,
                 fontweight='bold')    
    for i, j in enumerate(count_list):
        sns.histplot(data = df, x=j, ax=axes[i, 0],
                     kde=True,
                     line_kws = {'linestyle':'dashed',
                                 'linewidth':'1'},
                     color='#9BCD9B')
        sns.boxplot(data = df, x=j, ax=axes[i, 1],
                     color='#9BCD9B',
                     linewidth=0.5,
                     width=0.5,
                     medianprops={"color": "r", "linewidth": 1})

# %% [markdown]
# <div class="alert alert-success">
# <font color='blue'><b>Комментарий ментора</b></font><br>
# <font color='green'> ✔️ Хороший набор функций</font>

# %%
res_analysis(data_arc) #Файл data_arc_new.csv — данные об электродах
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   key                   14876 non-null  int64
#  1   Начало нагрева дугой  14876 non-null  object
#  2   Конец нагрева дугой   14876 non-null  object
#  3   Активная мощность     14876 non-null  float64
#  4   Реактивная мощность   14876 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 581.2+ KB
# None
#        Активная мощность  Реактивная мощность
# count           14876.00             14876.00
# mean                0.66                 0.44
# std                 0.26                 5.87
# min                 0.22              -715.48
# 25%                 0.47                 0.34
# 50%                 0.60                 0.44
# 75%                 0.83                 0.61
# max                 1.46                 1.27
# ...

# %%
hist_plot(data_arc, 8)

# %%
res_analysis(data_bulk) #Файл data_bulk_new.csv - данные о подаче сыпучих материалов (объём)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   252 non-null    float64
#  2   Bulk 2   22 non-null     float64
#  3   Bulk 3   1298 non-null   float64
#  4   Bulk 4   1014 non-null   float64
#  5   Bulk 5   77 non-null     float64
#  6   Bulk 6   576 non-null    float64
#  7   Bulk 7   25 non-null     float64
#  8   Bulk 8   1 non-null      float64
#  9   Bulk 9   19 non-null     float64
#  10  Bulk 10  176 non-null    float64
#  11  Bulk 11  177 non-null    float64
#  12  Bulk 12  2450 non-null   float64
#  13  Bulk 13  18 non-null     float64
#  14  Bulk 14  2806 non-null   float64
#  15  Bulk 15  2248 non-null   float64
# dtypes: float64(15), int64(1)
# memory usage: 391.2 KB
# None
#        Bulk 1  Bulk 2   Bulk 3   Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# ...

# %%
msno.heatmap(data_bulk, figsize=(10, 6), fontsize=8);

# %%
res_analysis(data_bulk_time) #Файл data_bulk_time_new.csv - данные о подаче сыпучих материалов (время)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   252 non-null    object
#  2   Bulk 2   22 non-null     object
#  3   Bulk 3   1298 non-null   object
#  4   Bulk 4   1014 non-null   object
#  5   Bulk 5   77 non-null     object
#  6   Bulk 6   576 non-null    object
#  7   Bulk 7   25 non-null     object
#  8   Bulk 8   1 non-null      object
#  9   Bulk 9   19 non-null     object
#  10  Bulk 10  176 non-null    object
#  11  Bulk 11  177 non-null    object
#  12  Bulk 12  2450 non-null   object
#  13  Bulk 13  18 non-null     object
#  14  Bulk 14  2806 non-null   object
#  15  Bulk 15  2248 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 391.2+ KB
# None
#                      Bulk 1               Bulk 2               Bulk 3  \
# ...

# %%
res_analysis(data_gas) #Файл data_gas_new.csv — данные о продувке сплава газом
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3239 non-null   int64
#  1   Газ 1   3239 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 50.7 KB
# None
#          Газ 1
# count  3239.00
# mean     11.00
# std       6.22
# min       0.01
# 25%       7.04
# 50%       9.84
# 75%      13.77
# max      78.00
# 'Количество явных дубликатов:'
# 0
# 'Доля пропушенных значений:'
# key      0.0
# Газ 1    0.0
# dtype: float64
# 'Диаграмма ненулевых значений:'

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
plt.suptitle('Распределение по количественным признакам',
             x=0.5,
             y=0.93,
             fontsize=12,
             fontweight='bold')    

# Гистограмма
sns.histplot(data=data_gas, x='Газ 1', ax=axes[0],
             kde=True,
             line_kws={'linestyle': 'dashed', 'linewidth': '1'},
             color='#9BCD9B')

# Boxplot
sns.boxplot(data=data_gas, x='Газ 1', ax=axes[1],
            color='#9BCD9B',
            linewidth=0.5,
            width=0.5,
            medianprops={"color": "r", "linewidth": 1});

# %%
res_analysis(data_temp) #Файл data_temp_new.csv — результаты измерения температуры
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18092 entries, 0 to 18091
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   key           18092 non-null  int64
#  1   Время замера  18092 non-null  object
#  2   Температура   14665 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 424.2+ KB
# None
#        Температура
# count     14665.00
# mean       1590.72
# std          20.39
# min        1191.00
# 25%        1580.00
# 50%        1590.00
# 75%        1599.00
# max        1705.00
# 'Количество явных дубликатов:'
# 0
# 'Доля пропушенных значений:'
# key              0.000000
# Время замера     0.000000
# Температура     18.942074
# dtype: float64
# 'Диаграмма ненулевых значений:'

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
plt.suptitle('Распределение по количественным признакам',
             x=0.5,
             y=0.93,
             fontsize=12,
             fontweight='bold')

# Гистограмма с KDE
sns.histplot(data=data_temp, x='Температура', ax=axes[0],
             kde=True,
             color='#9BCD9B')

# Boxplot
sns.boxplot(data=data_temp, x='Температура', ax=axes[1],
            color='#9BCD9B',
            linewidth=0.5,
            width=0.5,
            medianprops={"color": "r", "linewidth": 1})

plt.tight_layout()
plt.show()

# %%
res_analysis(data_wire) #Файл data_wire_new.csv — данные о проволочных материалах (объём)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   float64
#  2   Wire 2  1079 non-null   float64
#  3   Wire 3  63 non-null     float64
#  4   Wire 4  14 non-null     float64
#  5   Wire 5  1 non-null      float64
#  6   Wire 6  73 non-null     float64
#  7   Wire 7  11 non-null     float64
#  8   Wire 8  19 non-null     float64
#  9   Wire 9  29 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 240.8 KB
# None
#         Wire 1   Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  \
# count  3055.00  1079.00   63.00   14.00    1.00   73.00   11.00   19.00
# mean    100.90    50.58  189.48   57.44   15.13   48.02   10.04   53.63
# std      42.01    39.32   99.51   28.82     NaN   33.92    8.61   16.88
# ...

# %%
res_analysis(data_wire_time) #Файл data_wire_time_new.csv — данные о проволочных материалах (время)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   object
#  2   Wire 2  1079 non-null   object
#  3   Wire 3  63 non-null     object
#  4   Wire 4  14 non-null     object
#  5   Wire 5  1 non-null      object
#  6   Wire 6  73 non-null     object
#  7   Wire 7  11 non-null     object
#  8   Wire 8  19 non-null     object
#  9   Wire 9  29 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 240.8+ KB
# None
#                      Wire 1               Wire 2               Wire 3  \
# count                  3055                 1079                   63
# unique                 3055                 1079                   63
# top     2019-06-13 00:41:06  2019-06-28 18:11:32  2019-05-07 22:24:56
# freq                      1                    1                    1
#
# ...

# %% [markdown]
# Вывод по итогам исследовательского анализа данных
#
# ##### Файл data_arc_new.csv — данные об электродах
# * Датасет содержит 14876 значения
# * Явные дубликаты отсутствуют
# * Пропущенные значения отсутствуют
# * Активная мощность имеет минимальное значение 0.22, максимальное значение 1.46, среднее значение 0.66, медиана 0.60. Значения в диапазоне 1.4 - 1.5 рассматриваются на диаграмме распределения, как выбросы. Диграмма выглядит, как нормальное распределение скошенное вправо
# * Реактивная мощность имеет минимальное значение -715.48 (аномальное значение, которое по рекомендациям заказчика может быть исключено при дальнейшем анализе), максимальное значение 1.27, среднее значение 0.44, медиана 0.44
# ##### Файл data_bulk_new.csv - данные о подаче сыпучих материалов (объём)
# * Датасет содержит 3129 значения
# * Явные дубликаты отсутствуют
# * Пропущенные значения присутствуют в каждом столбце, согласно тепловой карте пропуске в столбце 12 наиболее связанны с пропусками в стобцах 14 и 15, также пропуски в столбце 2 связанны со столбцами 7 и 5. Остальные столбцы практически не связанны друг с другом. По
# * Возможно их заполнить нулями и после объединения данных целесообразно проверить корреляцию target
# ##### Файл data_bulk_time_new.csv - данные о подаче сыпучих материалов (время)
# * Датасет содержит 3129 значения
# * Явные дубликаты отсутствуют
# * Пропущенные значения присутствуют в каждом столбце, диаграмма схожа с данными о пропусках в данных о подаче сыпучих материалов
# * По рекомендациям заказчика данный датасет содержит контрольную информации и для дальнейшего анализа может не использоваться
# ##### Файл data_gas_new.csv — данные о продувке сплава газом
# * Датасет содержит 3239 значения
# * Явные дубликаты отсутствуют
# * Пропущенные значения отсутствуют
# * Объем подаваемого газа имеет минимальное значение 0.01, максимальное значение 78, среднее значение 11, медиана 9.84. Значения от 24 рассматриваются на диаграмме распределения, как выбросы. Данный вопрос необходимо уточнить у заказчика.
# ##### Файл data_temp_new.csv — результаты измерения температуры
# * Датасет содержит 18092 значения
# * Явные дубликаты отсутствуют
# * Пропущенные значения в столбце температура в количестве 3427, которые по рекомендациям заказчика должны быть удалены
# * Температура имеет минимальное значение 1191, максимальное значение 1705, среднее значение 1590.72, медиана 1590. * Значения с одним замером температуры, а также ниже среднего значения плавления стали (1500) необходимо удалить по рекомендациям заказчика
# ##### Файл data_wire_new.csv — данные о проволочных материалах (объём)
# * Датасет содержит 3081 значение
# * Явные дубликаты отсутствуют
# * Пропущенные значения есть в каждом столбце, в дальнейшем необходимо уточнить замену данных нулями
# ##### Файл data_wire_time_new.csv — данные о проволочных материалах (время)
# * Датасет содержит 3081 значение
# * Явные дубликаты отсутствуют
# * Пропущенные значения есть в каждом столбце, пропуски идентичны данным о проволочных материалах (объём)
# * По рекомендациям заказчика данный датасет содержит контрольную информации и для дальнейшего анализа может не использоваться

# %%
# Файл data_arc_new.csv — данные об электродах
data_arc.head(5)
# Out:
#    key Начало нагрева дугой  Конец нагрева дугой  Активная мощность  \
# 0    1  2019-05-03 11:02:14  2019-05-03 11:06:02           0.305130
# 1    1  2019-05-03 11:07:28  2019-05-03 11:10:33           0.765658
# 2    1  2019-05-03 11:11:44  2019-05-03 11:14:36           0.580313
# 3    1  2019-05-03 11:18:14  2019-05-03 11:24:19           0.518496
# 4    1  2019-05-03 11:26:09  2019-05-03 11:28:37           0.867133
#
#    Реактивная мощность
# 0             0.211253
# 1             0.477438
# 2             0.430460
# 3             0.379979
# 4             0.643691

# %%
data_arc = data_arc.rename(
    columns={
        'Начало нагрева дугой':'start_heating',
        'Конец нагрева дугой': 'finish_heating',
        'Активная мощность': 'active_power',
        'Реактивная мощность': 'reactive_power',
    }
)

# %%
data_arc['start_heating'] = pd.to_datetime(data_arc['start_heating'], format='%Y-%m-%d %H:%M:%S')
data_arc['finish_heating'] = pd.to_datetime(data_arc['finish_heating'], format='%Y-%m-%d %H:%M:%S')

# %%
#Удалим данные партий с отрицательной реактивной мощностью:
data_arc.query('reactive_power < 0')
# Out:
#        key       start_heating      finish_heating  active_power  \
# 9780  2116 2019-07-28 02:22:08 2019-07-28 02:23:57      0.705344
#
#       reactive_power
# 9780     -715.479924

# %%
data_arc.query('key == 2116')
# Out:
#        key       start_heating      finish_heating  active_power  \
# 9778  2116 2019-07-28 02:07:12 2019-07-28 02:09:14      0.787549
# 9779  2116 2019-07-28 02:13:10 2019-07-28 02:15:25      0.580263
# 9780  2116 2019-07-28 02:22:08 2019-07-28 02:23:57      0.705344
# 9781  2116 2019-07-28 02:29:11 2019-07-28 02:30:18      0.563641
#
#       reactive_power
# 9778        0.693881
# 9779        0.411498
# 9780     -715.479924
# 9781        0.408513

# %%
data_arc = data_arc.query('key != 2116')
data_arc.shape
# Out:
# (14872, 5)

# %% [markdown]
# <div class="alert alert-warning">
# <font color='blue'><b>Комментарий ментора</b></font><br>
# <font color='darkorange'>⚠️ Удаление аномалии хорошее решение, здесь можно подумать над заменой этого значение на основе других данных об этой партии</font>

# %%
#Произведем расчет полной мощности и добавим в новый столбец:
data_arc['full_power'] = (data_arc['active_power']**2 + data_arc['reactive_power']**2)**0.5

# %% [markdown]
# <div class="alert alert-success">
# <font color='blue'><b>Комментарий ментора</b></font><br>
# <font color='green'> ✔️ Классное применение формулы</font>

# %%
#Произведем расчет времени нагрева в секундах, а также полной энергии:
data_arc['heating_time'] = (data_arc['finish_heating'] - data_arc['start_heating']).dt.seconds
data_arc['full_energy'] = data_arc['full_power'] * data_arc['heating_time']

# %%
data_arc.head(5)
# Out:
#    key       start_heating      finish_heating  active_power  reactive_power  \
# 0    1 2019-05-03 11:02:14 2019-05-03 11:06:02      0.305130        0.211253
# 1    1 2019-05-03 11:07:28 2019-05-03 11:10:33      0.765658        0.477438
# 2    1 2019-05-03 11:11:44 2019-05-03 11:14:36      0.580313        0.430460
# 3    1 2019-05-03 11:18:14 2019-05-03 11:24:19      0.518496        0.379979
# 4    1 2019-05-03 11:26:09 2019-05-03 11:28:37      0.867133        0.643691
#
#    full_power  heating_time  full_energy
# 0    0.371123           228    84.616003
# 1    0.902319           185   166.928978
# 2    0.722536           172   124.276277
# 3    0.642824           365   234.630603
# 4    1.079934           148   159.830252

# %%
fig, ax = plt.subplots(figsize=(8, 4))
sns.boxplot(data=data_arc.iloc[:,1:-2])
plt.xlabel('Тип мощности')
plt.ylabel('Мощность')
plt.title('Распределение мощности');

# %% [markdown]
# Для дальнейшего анализа целесообразно объединить данные по номеру партии, построив сводную таблицу с расчетом и сумм энергии, мощностей, времени нагревания, а также произведем расчет количество циклов нагрева:

# %% [markdown]
# ##### Шаг 3. Объединение данных
# Объедините выбранные вами признаки в один датафрейм по ключу.

# %%
data_arc = data_arc.pivot_table(
    index='key', 
    values=['active_power',
            'reactive_power',
            'full_power',
            'heating_time',
            'full_energy',
            'start_heating'
           ], 
    aggfunc={'active_power': 'sum', 
             'reactive_power': 'sum', 
             'full_power': 'sum', 
             'heating_time': 'sum', 
             'full_energy': 'sum',
             'start_heating' : 'count'
            }
).reset_index().rename(
    columns={
        'start_heating':'number_of_heating'
    }
)

# %%
data_arc.columns
# Out:
# Index(['key', 'active_power', 'full_energy', 'full_power', 'heating_time',
#        'reactive_power', 'number_of_heating'],
#       dtype='object')

# %%
data_arc = data_arc[['key',
          'active_power',
          'reactive_power',
          'full_power',
          'heating_time',
          'full_energy',
          'number_of_heating']
        ]

# %%
display(data_arc.shape)
data_arc.head(5)
# Out:
# (3213, 7)
#    key  active_power  reactive_power  full_power  heating_time  full_energy  \
# 0    1      3.036730        2.142821    3.718736          1098   770.282114
# 1    2      2.139408        1.453357    2.588349           811   481.760005
# 2    3      4.063641        2.937457    5.019223           655   722.837668
# 3    4      2.706489        2.056992    3.400038           741   683.455597
# 4    5      2.252950        1.687991    2.816980           869   512.169934
#
#    number_of_heating
# 0                  5
# 1                  4
# 2                  5
# 3                  4
# 4                  4

# %%
#Файл data_bulk_new.csv - данные о подаче сыпучих материалов (объём)
data_bulk.head(5)
# Out:
#    key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# 0    1     NaN     NaN     NaN    43.0     NaN     NaN     NaN     NaN
# 1    2     NaN     NaN     NaN    73.0     NaN     NaN     NaN     NaN
# 2    3     NaN     NaN     NaN    34.0     NaN     NaN     NaN     NaN
# 3    4     NaN     NaN     NaN    81.0     NaN     NaN     NaN     NaN
# 4    5     NaN     NaN     NaN    78.0     NaN     NaN     NaN     NaN
#
#    Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 0     NaN      NaN      NaN    206.0      NaN    150.0    154.0
# 1     NaN      NaN      NaN    206.0      NaN    149.0    154.0
# 2     NaN      NaN      NaN    205.0      NaN    152.0    153.0
# 3     NaN      NaN      NaN    207.0      NaN    153.0    154.0
# 4     NaN      NaN      NaN    203.0      NaN    151.0    152.0

# %%
data_bulk.columns = data_bulk.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# Удалим признаки, в которых изначально имеется более 80% пропущенных значений, также заполним оставшиеся пропущенные значения нулями. Все столбцы, кроме bulk_12, bulk_14

# %%
data_bulk = data_bulk.drop(['bulk_1', 'bulk_2',
                            'bulk_3', 'bulk_4',
                            'bulk_5', 'bulk_6',
                            'bulk_7', 'bulk_8',
                            'bulk_9', 'bulk_10',
                            'bulk_11', 'bulk_13', 'bulk_15'], axis=1)
data_bulk = data_bulk.fillna(0)

# %%
display(data_bulk.shape)
display(data_bulk.head(5))
display(data_bulk.isna().sum())
# Out:
# (3129, 3)
#    key  bulk_12  bulk_14
# 0    1    206.0    150.0
# 1    2    206.0    149.0
# 2    3    205.0    152.0
# 3    4    207.0    153.0
# 4    5    203.0    151.0
# key        0
# bulk_12    0
# bulk_14    0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 4))
sns.boxplot(data=data_bulk.iloc[:,1:3], orient='h')
plt.ylabel('Сыпучий материал')
plt.xlabel('Объем')
plt.title('Распределение объема сыпучих материалов');

# %% [markdown]
# Вывод:
# В результате предобработки данных датасета о подаче сыпучих материалов (объём):
# Удалены признаки, в которых изначально имеется более 80% пропущенных значений, также заполним оставшиеся пропущенные значения нулями. Все столбцы, кроме bulk_12, bulk_14
# Пропущенные значения заполнены нулями

# %%
#Файл data_gas_new.csv — данные о продувке сплава газом
data_gas.head(5)
# Out:
#    key      Газ 1
# 0    1  29.749986
# 1    2  12.555561
# 2    3  28.554793
# 3    4  18.841219
# 4    5   5.413692

# %%
data_gas = data_gas.rename(
    columns={
        'Газ 1':'gas_1'
    }
)

# %%
#Файл data_temp_new.csv — результаты измерения температуры
data_temp.head(5)
# Out:
#    key         Время замера  Температура
# 0    1  2019-05-03 11:02:04       1571.0
# 1    1  2019-05-03 11:07:18       1604.0
# 2    1  2019-05-03 11:11:34       1618.0
# 3    1  2019-05-03 11:18:04       1601.0
# 4    1  2019-05-03 11:25:59       1606.0

# %%
data_temp = data_temp.rename(
    columns={
        'Время замера':'measuring_time',
        'Температура': 'temperature'
    }
)
data_temp['measuring_time'] = pd.to_datetime(data_temp['measuring_time'], format='%Y-%m-%d %H:%M:%S')

# %%
#Удалим партии с температурой менее 1500, партии где один замер температуры и партии с пропущенными значениями:
data_temp.query('temperature < 1500')
# Out:
#         key      measuring_time  temperature
# 4883    867 2019-06-06 08:03:39       1191.0
# 6784   1214 2019-06-18 08:01:03       1208.0
# 9050   1619 2019-07-03 02:34:41       1218.0
# 11495  2052 2019-07-25 08:49:15       1227.0
# 14283  2561 2019-08-12 18:49:29       1204.0

# %%
delete_keys = data_temp.query('temperature < 1500')['key'].tolist()
delete_keys
# Out:
# [867, 1214, 1619, 2052, 2561]

# %% [markdown]
# <div class="alert alert-success">
# <font color='blue'><b>Комментарий ментора</b></font><br>
# <font color='green'> ✔️ Все верно, эти партии нам не нужны</font>

# %%
delete_keys += data_temp[data_temp['temperature'].isna()]['key'].unique().tolist()

# %%
keys_quantity = data_temp.pivot_table(index='key',
                                      values=['temperature'],
                                      aggfunc='count').reset_index()

# %%
delete_keys += keys_quantity.query('temperature < 2')['key'].tolist()

# %%
len(delete_keys)
# Out:
# 1485

# %%
data_temp = data_temp.query('key not in @delete_keys')
data_temp.shape
# Out:
# (13903, 3)

# %%
data_temp.head()
# Out:
#    key      measuring_time  temperature
# 0    1 2019-05-03 11:02:04       1571.0
# 1    1 2019-05-03 11:07:18       1604.0
# 2    1 2019-05-03 11:11:34       1618.0
# 3    1 2019-05-03 11:18:04       1601.0
# 4    1 2019-05-03 11:25:59       1606.0

# %%
#Определение начальной и конечной температур замеров
data_temp = data_temp.sort_values(
    by='measuring_time').pivot_table(
    index='key', values=['temperature'], aggfunc=['first', 'last']
).reset_index()
data_temp.columns = ['key', 'first_temperture', 'last_temperature']
data_temp.head(5)
# Out:
#    key  first_temperture  last_temperature
# 0    1            1571.0            1613.0
# 1    2            1581.0            1602.0
# 2    3            1596.0            1599.0
# 3    4            1601.0            1625.0
# 4    5            1576.0            1602.0

# %%
data_temp.shape
# Out:
# (2471, 3)

# %%
fig, ax = plt.subplots(figsize=(10, 4))
sns.boxplot(data=data_temp.iloc[:,1:3], orient='h')
plt.ylabel('Тип температуры')
plt.xlabel('Температура')
plt.title('Распределение начальной и конечной температуры');

# %%
#Файл data_wire_new.csv — данные о проволочных материалах (объём)
data_wire.head(5)
# Out:
#    key     Wire 1   Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  \
# 0    1  60.059998      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2  96.052315      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    3  91.160157      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3    4  89.063515      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4    5  89.238236  9.11456     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Wire 9
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
data_wire.columns = data_wire.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# Удалим признаки, в которых изначально имеется более 80% пропущенных значений, также заполним оставшиеся пропущенные значения нулями. Все столбцы, кроме wire_1

# %%
data_wire.columns
# Out:
# Index(['key', 'wire_1', 'wire_2', 'wire_3', 'wire_4', 'wire_5', 'wire_6',
#        'wire_7', 'wire_8', 'wire_9'],
#       dtype='object')

# %%
data_wire = data_wire.drop(['wire_2', 'wire_3', 'wire_4',
                            'wire_5', 'wire_6', 'wire_7',
                            'wire_8', 'wire_9'], axis=1)
data_wire = data_wire.fillna(0)

# %%
display(data_wire.shape)
display(data_wire.head(5))
display(data_wire.isna().sum())
# Out:
# (3081, 2)
#    key     wire_1
# 0    1  60.059998
# 1    2  96.052315
# 2    3  91.160157
# 3    4  89.063515
# 4    5  89.238236
# key       0
# wire_1    0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 4))
sns.boxplot(data=data_wire.iloc[:,1:2], orient='h')
plt.ylabel('Тип проволочного материала')
plt.xlabel('Объем')
plt.title('Распределение объема проволочного материала');

# %% [markdown]
# **Файл data_arc_new.csv — данные об электродах**
#
# 1. Переименнованны столбцы по правилам PEP8
#
# 2. Удалены данные партий с отрицательной реактивной мощностью:
#
# 3. Произведен расчет полной мощности и добавлен в новый столбец
#
# 4. Произведен расчет времени нагрева в секундах, а также полной энергии, данные добавлены в новые столбцы
#
# 5. Объединенны данные по номеру партии, в сводной таблице с расчетом и сумм энергии, мощностей, времени нагревания, а также произведем расчет количество циклов нагрева
#
# 6. В результате полной предобработки данных датасета с данными об электродах, получили новый датафрем размерностью 3213 строку и 7 столбцов, содержащий новые признаки:
#
# - 'full_power' - полная мощность;
# - 'heating_time' - время нагрева (секунды);
# - 'full_energy' - полная энергия;
# - 'number_of_heating' количество циклов нагрева каждой партии
#
# **Файл data_bulk_new.csv - данные о подаче сыпучих материалов (объём)**
#
# 1. Переименнованны столбцы по правилам PEP8
#
# 2. Удалены признаки, в которых изначально имеется более 80% пропущенных значений, также заполненны оставшиеся пропущенные значения нулями. Все столбцы, кроме bulk_12, bulk_14
#
# 3. В результате полной предобработки данных датасета, получили новый датафрем размерностью 3129 строку и 3 столбца
#
#
# **Файл data_gas_new.csv — данные о продувке сплава газом**
#
# 1. Переименнованны столбцы по правилам PEP8
#
# 2. Явные дополнительные преобразования не требуется, анализ выбросов по реколмендации заказчика произведем после создания тренировочной выборки
#
# **Файл data_temp_new.csv — результаты измерения температуры**
#
# 1. Переименнованны столбцы по правилам PEP8
#
# 2. Удалены партии с температурой менее 1500, партии где один замер температуры и партии с пропущенными значениями:
#
# 3. Выполнено определение начальной и конечной температур замеров:
#
# 4. В результате полной предобработки данных датасета, получили новый датафрем размерностью 2471 строку и 3 столбца
#
#
# **Файл data_wire_new.csv — данные о проволочных материалах (объём)**
#
# 1. Переименнованны столбцы по правилам PEP8
#
# 2. Удалены признаки, в которых изначально имеется более 80% пропущенных значений, также заполним оставшиеся пропущенные значения нулями. Все столбцы, кроме wire_1
#
# 3. В результате полной предобработки данных датасета, получили новый датафрем размерностью 3081 строку и 2 столбца

# %%
data = data_arc.merge(data_bulk, on='key', how='inner').merge(data_gas, on='key', how='inner'). \
merge(data_temp, on='key', how='inner').merge(data_wire, on='key', how='inner')

# %%
data.shape
# Out:
# (2324, 13)

# %%
data.head(5)
# Out:
#    key  active_power  reactive_power  full_power  heating_time  full_energy  \
# 0    1      3.036730        2.142821    3.718736          1098   770.282114
# 1    2      2.139408        1.453357    2.588349           811   481.760005
# 2    3      4.063641        2.937457    5.019223           655   722.837668
# 3    4      2.706489        2.056992    3.400038           741   683.455597
# 4    5      2.252950        1.687991    2.816980           869   512.169934
#
#    number_of_heating  bulk_12  bulk_14      gas_1  first_temperture  \
# 0                  5    206.0    150.0  29.749986            1571.0
# 1                  4    206.0    149.0  12.555561            1581.0
# 2                  5    205.0    152.0  28.554793            1596.0
# 3                  4    207.0    153.0  18.841219            1601.0
# 4                  4    203.0    151.0   5.413692            1576.0
#
#    last_temperature     wire_1
# 0            1613.0  60.059998
# 1            1602.0  96.052315
# ...

# %%
data.tail(5)
# Out:
#        key  active_power  reactive_power  full_power  heating_time  \
# 2319  2495      3.168133        2.210936    3.868721           723
# 2320  2496      4.174918        2.872031    5.070316           940
# 2321  2497      3.605239        2.452092    4.360918           569
# 2322  2498      3.202310        2.239820    3.909917           750
# 2323  2499      1.737084        1.296836    2.169252           883
#
#       full_energy  number_of_heating  bulk_12  bulk_14      gas_1  \
# 2319   694.177326                  4    256.0    129.0   7.125735
# 2320   815.818538                  6    256.0    129.0   9.412616
# 2321   823.020520                  3    230.0    124.0   6.271699
# 2322   581.810739                  5    206.0    129.0  14.953657
# 2323   532.386183                  4    233.0    126.0  11.336151
#
#       first_temperture  last_temperature      wire_1
# 2319            1570.0            1591.0   89.150879
# 2320            1554.0            1591.0  114.179527
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font color='blue'><b>Комментарий ментора</b></font><br>
# <font color='green'> ✔️ Данные объеденены и с ними можно работать</font>

# %% [markdown]
# #### Вывод по объединению таблиц
#
# 1. В результате проверочных операций не должно оставаться ключей, с номерами более чем 2500, что подтвержено методом df.tail().
#
# 2. Итоговый датафрейм состоит из 2324 строк и 13 столбцов, что также соответствует рекомендациям заказчика (не более 2332 ключей)
# _____

# %% [markdown]
# #### Шаг 4. Исследовательский анализ и предобработка данных объединённого датафрейма
# Выполните исследовательский анализ объединённого датафрейма, визуализируйте распределения признаков и при необходимости выполните предобработку. Проведите корреляционный анализ.

# %%
#Удалим столбец 'key'
data = data.drop('key', axis=1)

# %%
plt.figure(figsize=(15, 15))
plt.title('Корреляция признаков', fontsize=20)
plt.rcParams.update({'font.size': 7})
sns.heatmap(data.corr(method='spearman'), annot = True, cmap='coolwarm', fmt ='.2f')

plt.show()

# %% [markdown]
# Видно из тепловой  карты корреляции, максимиально коррелируют с целевым признаком 'last_temperature':
#
# - активная мощность 'active_power';
# - полная мощность 'full_power';
# - время нагрева 'heating_time';
# - полная энергия 'full_energy';
# - количество циклов нагрева 'number_of_heating';
# - добавка 'bulk_12';
# - первичная температура 'first_temperature';
# - проволока 'wire_1'

# %% [markdown]
# Удалим лишние столбцы, для которых коэффициент корреляции больше 0,9.

# %%
data = data.drop(['active_power', 'reactive_power', 'full_power'], axis=1)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.hist(figsize=(15, 15), bins=20)
plt.suptitle('Гистограммы распределения признаков итогового датасета', fontsize=12);

# %% [markdown]
# #### Шаг 5. Подготовка данных
# Выполните подготовку данных для обучения модели. Разделите данные на две выборки, при масштабировании и кодировании учитывайте особенности данных и моделей.

# %%
data.head()
# Out:
#    heating_time  full_energy  number_of_heating  bulk_12  bulk_14      gas_1  \
# 0          1098   770.282114                  5    206.0    150.0  29.749986
# 1           811   481.760005                  4    206.0    149.0  12.555561
# 2           655   722.837668                  5    205.0    152.0  28.554793
# 3           741   683.455597                  4    207.0    153.0  18.841219
# 4           869   512.169934                  4    203.0    151.0   5.413692
#
#    first_temperture  last_temperature     wire_1
# 0            1571.0            1613.0  60.059998
# 1            1581.0            1602.0  96.052315
# 2            1596.0            1599.0  91.160157
# 3            1601.0            1625.0  89.063515
# 4            1576.0            1602.0  89.238236

# %%
data['bulk_sum'] = data['bulk_12'] + data['bulk_14']
data['new'] = data['full_energy'] * data['heating_time']
data = data.drop(['full_energy', 'heating_time', 'bulk_12'], axis=1)

# %% [markdown]
# <div class="alert alert-warning">
# <font color='blue'><b>Комментарий ментора v6</b></font><br>
# <font color='darkorange'>⚠️ Какой физический смысл ты закладываешь в признак new?</font>

# %% [markdown]
# <div class="alert alert-danger">
# <font color='blue'><b>Комментарий ментора</b></font><strike>
# <br><font color='crimson'> ❌ Размер выборок 3:1 или 75:25, а не 60:40

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: Поправил</b></font>
# </div>

# %% [markdown]
# <div class='well'>
# <font color='blue'><b>Комментарий ментора V6</b></font>
# <font color='blue'><br> Все, что ты делал по признакам до этого привело тебя к правильному датасету для небустинговых моделей. В бустинге принципиально создать и добавлять как ожно больше признаков

# %%
df = data_arc.merge(file_download('data_bulk_new.csv').fillna(0), on='key').\
              merge(file_download('data_wire_new.csv').fillna(0), on='key').\
              merge(data_gas, on='key'). \
              merge(data_temp, on='key')

df = df.set_index('key', drop=True)
df
# Out:
#       active_power  reactive_power  full_power  heating_time  full_energy  \
# key
# 1         3.036730        2.142821    3.718736          1098   770.282114
# 2         2.139408        1.453357    2.588349           811   481.760005
# 3         4.063641        2.937457    5.019223           655   722.837668
# 4         2.706489        2.056992    3.400038           741   683.455597
# 5         2.252950        1.687991    2.816980           869   512.169934
# ...            ...             ...         ...           ...          ...
# 2495      3.168133        2.210936    3.868721           723   694.177326
# 2496      4.174918        2.872031    5.070316           940   815.818538
# 2497      3.605239        2.452092    4.360918           569   823.020520
# 2498      3.202310        2.239820    3.909917           750   581.810739
# 2499      1.737084        1.296836    2.169252           883   532.386183
#
#       number_of_heating  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  \
# ...

# %%
data = df.copy()

X = data.drop('last_temperature', axis=1)
y = data['last_temperature']


X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.25, 
    random_state=RANDOM_STATE
)

# %%
display(X_train.shape)
display(X_test.shape)
display(y_train.shape)
display(y_test.shape)
# Out:
# (1743, 32)
# (581, 32)
# (1743,)
# (581,)

# %%
X_train
# Out:
#       active_power  reactive_power  full_power  heating_time  full_energy  \
# key
# 1685      4.563226        3.337872    5.659666           790   708.936157
# 226       2.761088        1.960592    3.387887           857   626.304985
# 1416      1.409930        1.059938    1.763954           416   365.968081
# 2202      3.035365        2.100599    3.692461          1230   800.406548
# 2274      2.015934        1.570338    2.559238           757   688.968595
# ...            ...             ...         ...           ...          ...
# 129       2.413369        1.738182    2.974261           591   444.547272
# 144       4.004201        2.852825    4.919869          1052   838.745426
# 388       3.357306        2.430183    4.149239           773   586.130965
# 1621      3.130869        2.116093    3.780969           564   545.601157
# 517       1.710564        1.152855    2.063520           791   390.020493
#
#       number_of_heating  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  \
# ...

# %% [markdown]
# Пайплайн для подготовки данных:

# %%
num_columns = X.columns.tolist()

# %% [markdown]
# <div class="alert alert-danger">
# <font color='blue'><b>Комментарий ментора v3</b></font><strike>
# <br><font color='crimson'> ❌ Зачем второй раз делить выборку и откуда это RS?

# %% [markdown]
# ##### Шаг 6. Обучение моделей машинного обучения
# Обучите как минимум две модели. Хотя бы для одной из них подберите как минимум два гиперпараметра.

# %% [markdown]
# <div class='well'>
# <font color='blue'><b>Комментарий ментора V6</b></font>
# <font color='blue'><br> В предобработке убрал масштабирование для бустингов LightGBM и CatBoost. Оно ненужно. В каждой модели добавил гиперпараметры, которые дают как раз лучший результат. Мультиколлинеарность не требуется для них обрабатывать

# %%
# Предобработка
data_preprocessor = ColumnTransformer([
    ('num', 'passthrough', num_columns)
])

# 1. Linear Regression
pipe_lr = Pipeline([
    ('preprocessor', data_preprocessor),
    ('model', LinearRegression())
])

param_grid_lr = {
    'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
}

search_lr = RandomizedSearchCV(
    pipe_lr,
    param_distributions=param_grid_lr,
    cv=5,
    scoring='neg_mean_absolute_error',
    n_iter=3,
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# 2. LightGBM
pipe_lgbm = Pipeline([
    ('preprocessor', data_preprocessor),
    ('model', LGBMRegressor(verbose=-1, random_state=RANDOM_STATE))
])

param_grid_lgbm = {
    'model__max_depth': [2, 5, 8, 10, 12],
#     'model__num_leaves': [2, 3, 5, 7, 10],
    'model__n_estimators': [31, 50, 100, 200],
#     'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
}

search_lgbm = RandomizedSearchCV(
    pipe_lgbm,
    param_distributions=param_grid_lgbm,
    cv=3,
    scoring='neg_mean_absolute_error',
    n_iter=10,
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# 3. CatBoost
pipe_cat = Pipeline([
    ('preprocessor', data_preprocessor),
    ('model', CatBoostRegressor(
        iterations=1000,
#     early_stopping_rounds=50,
#     loss_function='MAE',
    verbose=False,
    random_state=RANDOM_STATE
    ))
])

param_grid_cat = {
    'model__max_depth': [x for x in range(2,6)],
    'model__learning_rate': [x/20 for x in range(1,20)],
#     'model__l2_leaf_reg': [x*100 for x in range(1,6)],
    'model__subsample': [x/10 for x in range(1,10)],
#     'model__bagging_temperature': [x/2 for x in range(1,5)],
    'model__iterations' : [100, 250, 500, 1000]
}
search_cat = RandomizedSearchCV(
    pipe_cat,
    param_distributions=param_grid_cat,
    cv=5,
    scoring='neg_mean_absolute_error',
    n_iter=50,
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# %% [markdown]
# <div class="alert alert-danger">
# <font color='blue'><b>Комментарий ментора v3</b></font><strike>
# <br><font color='crimson'> ❌ В нашей задачен не используется кросс-валидация по времени

# %%
search_lr.fit(X_train, y_train)
print ('Метрика линейной регрессии на кросс-валидации:', -search_lr.best_score_)
# Out:
# Метрика линейной регрессии на кросс-валидации: 6.601694116366933

# %%
search_lgbm.fit(X_train, y_train)
print('Лучшая модель LightGBM и её параметры:\n\n', search_lgbm.best_estimator_)
print ('Метрика лучшей модели на кросс-валидации:', -search_lgbm.best_score_)
# Out:
# Лучшая модель LightGBM и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   ['active_power',
#                                                    'reactive_power',
#                                                    'full_power', 'heating_time',
#                                                    'full_energy',
#                                                    'number_of_heating',
#                                                    'Bulk 1', 'Bulk 2', 'Bulk 3',
#                                                    'Bulk 4', 'Bulk 5', 'Bulk 6',
#                                                    'Bulk 7', 'Bulk 8', 'Bulk 9',
#                                                    'Bulk 10', 'Bulk 11',
#                                                    'Bulk 12', 'Bulk 13',
#                                                    'Bulk 14', 'Bulk 15',
# ...

# %%
search_cat.fit(X_train, y_train)
print('Лучшая модель CatBoostRegressor и её параметры:\n\n', search_cat.best_estimator_)
print ('Метрика лучшей модели на кросс-валидации:', -search_cat.best_score_)
# Out:
# Лучшая модель CatBoostRegressor и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   ['active_power',
#                                                    'reactive_power',
#                                                    'full_power', 'heating_time',
#                                                    'full_energy',
#                                                    'number_of_heating',
#                                                    'Bulk 1', 'Bulk 2', 'Bulk 3',
#                                                    'Bulk 4', 'Bulk 5', 'Bulk 6',
#                                                    'Bulk 7', 'Bulk 8', 'Bulk 9',
#                                                    'Bulk 10', 'Bulk 11',
#                                                    'Bulk 12', 'Bulk 13',
# ...

# %% [markdown]
# <div class='alert alert-warning'>
# <font color='blue'><b>Комментарий ментора</b></font><br><strike>
# <font color='darkorange'>⚠️ Классный пайплайн. Единственное не понятно, получится ли опробовать все модели? Каждую модель лучше разнести в свой RandomizedSearchCV, чтобы получить сравнительную таблицу для заказчика. Может полчуится так, что никогда лучшая модель может не попасть на вывод</font>

# %% [markdown]
# <div class='well'>
# <font color='blue'><b>Комментарий ментора V6</b></font>
# <font color='blue'><br> Как видишь модель на кросс-валидации стала еще лучше. Конечно, мы не защитиль от резкого переобучения, но оно позволила нам понищить метрику на тестовой

# %% [markdown]
# ##### Шаг 7. Выбор лучшей модели
# Выберите лучшую модель и проверьте её качество на тестовой выборке.

# %%
best_model = search_cat.best_estimator_
best_model_preprocessor = search_cat.best_estimator_['preprocessor']
search_cat.best_params_
# Out:
# {'model__subsample': 0.4,
#  'model__max_depth': 3,
#  'model__learning_rate': 0.05,
#  'model__iterations': 1000}

# %%
# Модель ментора
predict_test = best_model.predict(X_test)
MAE_score = mean_absolute_error(y_test, predict_test)

print(f'MAE на тестовой выборке: {MAE_score:.2f}')
# Out:
# MAE на тестовой выборке: 6.64

# %%
# Модель студента
predict_test = best_model.predict(X_test)
MAE_score = mean_absolute_error(y_test, predict_test)

print(f'MAE на тестовой выборке: {MAE_score:.2f}')
# Out:
# MAE на тестовой выборке: 6.96

# %%
r2 = r2_score(y_test, predict_test)

print(f'r2 на тестовой выборке: {r2:.2f}')
# Out:
# r2 на тестовой выборке: 0.26

# %% [markdown]
# <div class="alert alert-danger">
# <font color='blue'><b>Комментарий ментора v2</b></font><strike>
# <br><font color='crimson'> ❌ На тесте должна получиться метрика ниже 6.8. Модель заметно переобучилось (6,33 -> 7.03). Попробуй к гиперпараметрам применить следующее:
# <br> - depth заменить на max_depth. Бустинг должен сам настроиться, до какого порога остановиться. Из-за жесткой фиксации как раз может получиться переобучение
# <br> - l2_leaf_reg сделать как степень числа 10 - 0,01, 0,1, 1, 10, 100 и так далее на твое усмотрение
# <br> - n_iter в RSCV сделать равным 20%-30% от общего числа комбинаций параметров. Сейчас у тебя 10 проходов при 180 комбинациях

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: Не помогло избежать переобучения </b></font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font color='blue'><b>Комментарий ментора v3<b></font><br>
# <font color='green'> ✔️ Переобучение было, когда cv был 6,3, а тест 7,0. Сейчас нормально поулчилось сделать метрику, хоть и способом, который не разрешен. То есть разница между 6,56 и 6,69 нормальная</font>

# %% [markdown]
# <div class="alert alert-danger">
# <font color='blue'><b>Комментарий ментора v4</b></font><strike>
# <br><font color='crimson'> ❌ Откуда взяты гиперпараметры? Часть из них совпадает с кросс-валидацией. Очень странно показываать заказчику качество на cv на одном наборе параметров, а в тест заводить другие. Повтори шаги из комментария выше и верни все признаки. Мне все больше кажется, что задача решается не самостоятельно

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: Задача решается самостоятельно, но проблема переобучения не дает получить требуемую точность, я старался доп настрйками вручную добиться подходящих. Вернул предыдущий вариант, но я не знаю как получить требуемый уровень точности на тесте </b></font>
# </div>

# %% [markdown]
# Данное значение r2 говорит, что прогноз модели лучше, чем среднеее арифметическое фактических целевых значений, но модель не идеальна и будет вести себя среднее с неизвестным набором данных.

# %% [markdown]
# #### Cравнение с константной моделью DummyRegressor

# %%
constant_model = DummyRegressor(strategy='median')
constant_model.fit(X_train, y_train)
constant_predict_test = constant_model.predict(X_test)
constant_MAE_score = mean_absolute_error(y_test, constant_predict_test)

print(f'MAE констатной модели на тестовой выборке: {constant_MAE_score:.2f}')
# Out:
# MAE констатной модели на тестовой выборке: 8.23

# %% [markdown]
# Метрика CatBoostRegressor лучше, чем на константной модели

# %% [markdown]
# ### Оценка важности признаков

# %%
feature_importance = pd.Series(
    search_cat.best_estimator_._final_estimator.feature_importances_,
    index=X_test.columns
).sort_values(ascending=False)

# %%
 plt.figure(figsize=(8,4))

plot_data = feature_importance.sort_values(ascending=False)

sns.barplot(x=plot_data, y=plot_data.index)

plt.title('Важность признаков')
plt.xlabel('Критерий важности')
plt.ylabel('Названия признаков')
plt.show()

# %% [markdown]
# <div class='well'>
# <font color='blue'><b>Комментарий ментора V6</b></font>
# <font color='blue'><br> И здесь можно сравнить, что признаки, которые ты удалил улучшили качество модели.

# %%
 plt.figure(figsize=(8,4))

plot_data = feature_importance.sort_values(ascending=False)

sns.barplot(x=plot_data, y=plot_data.index)

plt.title('Важность признаков')
plt.xlabel('Критерий важности')
plt.ylabel('Названия признаков')
plt.show()

# %% [markdown]
# **Вывод по важности признаков:**
#
# - Наиболее важным признаками являются первичная температура и время нагрева
# - Также существенное влияние оказывают объем сыпучего материала 'bulk_12' и объем проволоки 'wire_1'
# - Минимально значимый признак - количество циклов нагрева

# %% [markdown]
# #### Вывод по обучению моделей
#
# 1. Для обучения и оценки моделей данные были разбиты в следующих проворциях: кросс-валидация 75%, тест 25 %
#
# 2. Для проекта использовались модели LGBMRegressor, CatBoostRegressor и DecisionTreeRegressor с подготовкой данных с помощью Pipeline
#
# 3. Лучшей моделью по итогам кросс-валидиации является CatBoostRegressor
#
# 4. Метрика лучшей модели на кросс-валидации: МАЕ = 6.55
#
# 5. Параметры лучшей модели: RANDOM_STATE = 160625,
#
#    learning_rate=0.005,
#                               depth=4,
#                               iterations=5000,
#                               early_stopping_rounds=20,
#                               l2_leaf_reg=100,
#                               min_data_in_leaf=50,
#                               subsample=0.6,
#                               colsample_bylevel=0.6,
#                               bagging_temperature=1.0,
#                               leaf_estimation_iterations=5,
#                               grow_policy='Lossguide',
#                               loss_function='MAE',
#                               random_strength=30
#     'models': CatBoostRegressor
#
# 6. Метрика лучшей модели на тестовой выборке MAE = 6.31, что соответствует требованиям заказчика
#
# 7. Метрика r2 на тестовой выборке равна 0.298, данное значение говорит, что прогноз модели лучше, чем среднеее арифметическое фактических целевых значений, но модель не идельна и будет вести себя среднее с неизвестным набором данных
#
# 8. MAE констатной модели DummyRegressor на тестовой выборке: 8.22, что хуже CatBoostRegressor
#
# 9. Наиболее важным признаками являются первичная температура и время нагрева, также существенное влияние оказывают объем проволоки 'wire_1' и объем сыпучего материала 'bulk_12'. Минимально значимый признак - количество циклов нагрева.

# %% [markdown]
# ##### Шаг 8. Общий вывод и рекомендации заказчику
# Сделайте общий вывод о проделанной работе: опишите основные этапы работы, полученные результаты и дайте рекомендации для бизнеса.

# %% [markdown]
# #### Итоговый вывод к проекту
#
# **Целью данного проекта** являлась оптимизация производственных расходов металлургического комбината, с помощью построения модели машинного обучения, которая предсказывает температуру сплава.
#
# Данная модель позволит снизить затраты на электричество, обслуживание и ремонты.
#
# - Целевая переменная target - последняя температура по всей партии
# - Целевая метрика - MAE (нужно получить не более 6.8 на тесте)
#
# Для решения данной задачи заказчиком было предоставлено семь датасетов:
#
# - data_arc_new.csv — данные об электродах;
#
# - data_bulk_new.csv — данные о подаче сыпучих материалов (объём);
#
# - data_bulk_time_new.csv — данные о подаче сыпучих материалов (время);
#
# - data_gas_new.csv — данные о продувке сплава газом;
#
# - data_temp_new.csv — результаты измерения температуры;
#
# - data_wire_new.csv — данные о проволочных материалах (объём);
#
# - data_wire_time_new.csv — данные о проволочных материалах (время).
#
# После загрузки данных, был произведен исследовательский анализ данных, сформированны вопросы заказчику, которые обсуждались в рамках совещания.
#
# **Итог:** для дальнейшего анализа и предобработи рассмотренно 5 таблиц:
#
# **Файл data_arc_new.csv — данные об электродах**
#
# 1. Переименнованны столбцы по правилам PEP8
#
# 2. Удалены данные партий с отрицательной реактивной мощностью:
#
# 3. Произведен расчет полной мощности и добавлен в новый столбец
#
# 4. Произведен расчет времени нагрева в секундах, а также полной энергии, данные добавлены в новые столбцы
#
# 5. Объединенны данные по номеру партии, в сводной таблице с расчетом и сумм энергии, мощностей, времени нагревания, а также произведем расчет количество циклов нагрева
#
# 6. В результате полной предобработки данных датасета с данными об электродах, получили новый датафрем размерностью 3213 строку и 7 столбцов, содержащий новые признаки:
#
# - 'full_power' - полная мощность;
# - 'heating_time' - время нагрева (секунды);
# - 'full_energy' - полная энергия;
# - 'number_of_heating' количество циклов нагрева каждой партии
#
# **Файл data_bulk_new.csv - данные о подаче сыпучих материалов (объём)**
#
# 1. Переименнованны столбцы по правилам PEP8
#
# 2. Удаленны признаки, в которых изначально имеется более 80% пропущенных значений, также заполненны оставшиеся пропущенные значения нулями. Все столбцы, кроме bulk_12, bulk_14
#
# 3. В результате полной предобработки данных датасета, получили новый датафрем размерностью 3129 строку и 3 столбца
#
#
# **Файл data_gas_new.csv — данные о продувке сплава газом**
#
# 1. Переименнованны столбцы по правилам PEP8
#
# 2. Явные дополнительные преобразования не требуется, анализ выбросов по реколмендации заказчика произведем после создания тренировочной выборки
#
# **Файл data_temp_new.csv — результаты измерения температуры**
#
# 1. Переименнованны столбцы по правилам PEP8
#
# 2. Удалены партии с температурой менее 1500, партии где один замер температуры и партии с пропущенными значениями:
#
# 3. Выполнено определение начальной и конечной температур замеров:
#
# 4. В результате полной предобработки данных датасета, получили новый датафрем размерностью 2471 строку и 3 столбца
#
#
# **Файл data_wire_new.csv — данные о проволочных материалах (объём)**
#
# 1. Переименнованны столбцы по правилам PEP8
#
# 2. Удалены признаки, в которых изначально имеется более 80% пропущенных значений, также заполним оставшиеся пропущенные значения нулями. Все столбцы, кроме wire_1
#
# 3. В результате полной предобработки данных датасета, получили новый датафрем размерностью 3081 строку и 2 столбца
#
#
# Предобработанные данные 5-ти датасетов были объединены по ключу 'key' методом INNER
#
# Итоговый датафрейм состоит из 2324 строк и 13 столбцов, что также соответствует рекомендациям заказчика (не более 2332 ключей)
#
# Согласно данным из тепловой карты корреляции, выявленно, что максимиально коррелируют с целевым признаком **'last_temperature':**
#
# - активная мощность 'active_power';
# - полная мощность 'full_power';
# - время нагрева 'heating_time';
# - полная энергия 'full_energy';
# - количество циклов нагрева 'number_of_heating';
# - добавка 'bulk_12';
# - первичная температура 'first_temperature';
# - проволока 'wire_1'
#
# 1. Для обучения и оценки моделей данные были разбиты в следующих проворциях: кросс-валидация 60%, тест 40 %
#
# 2. Для проекта использовались модели LGBMRegressor, CatBoostRegressor и DecisionTreeRegressor с подготовкой данных с помощью Pipeline
#
# 3. Лучшей моделью по итогам кросс-валидиации является CatBoostRegressor
#
# 4. Метрика лучшей модели на кросс-валидации: МАЕ = 6.31
#
# 5. Параметры лучшей модели: RANDOM_STATE = 160625,
#
#     learning_rate=0.005,
#                               depth=4,
#                               iterations=5000,
#                               early_stopping_rounds=20,
#                               l2_leaf_reg=100,
#                               min_data_in_leaf=50,
#                               subsample=0.6,
#                               colsample_bylevel=0.6,
#                               bagging_temperature=1.0,
#                               leaf_estimation_iterations=5,
#                               grow_policy='Lossguide',
#                               loss_function='MAE',
#                               random_strength=30
#     'models': CatBoostRegressor
#
# 6. Метрика лучшей модели на тестовой выборке MAE = 6.79, что соответствует требованиям заказчика
#
# 7. Метрика r2 на тестовой выборке равна 0.298, данное значение говорит, что прогноз модели лучше, чем среднеее арифметическое фактических целевых значений, но модель не идельна и будет вести себя среднее с неизвестным набором данных
#
# 8. MAE констатной модели DummyRegressor на тестовой выборке: 8.22, что хуже CatBoostRegressor
#
# 9. Наиболее важным признаками являются первичная температура и время нагрева, также существенное влияние оказывают объем проволоки 'wire_1' и объем сыпучего материала 'bulk_12'. Минимально значимый признак - количество циклов нагрева.

# %% [markdown]
# **Рекомендации заказчику**
#
# Для улучшения результатов решения задачи рассмотреть следующие шаги:
#
# - рассмотреть применение нейронных сетей для постоения прогноза целевого признака, что должно уменьшить ошибку и улучшить метрику
#
# - рассмотреть исключение (возможно) аномальных значений признаков в объединенном датасете, что должно улучшить обучение модели и предсказание на новых данных

# %% [markdown]
# <div class="well">
# <div class="alert alert-success">
# <font color='blue'><b>Итоговый комментарий ментора:</b></font>
# <br><font color='green'> ✔️ Данные подготовлены и объеденены
# <br> ✔️ Модели обучены
# <br> ✔️ Найдена лучшая модель
# <br> ✔️ Проверена адекватность и определены значимые признаки
# </font>
# </div>
# <div class="alert alert-warning">
# <br><font color='blue'>Можно проект улучшить:</font>
# <br><font color='darkorange'>⚠️ Обработать по другому аномалию с мощностью</font><strike>
# <br><font color='darkorange'>⚠️ Разнести из пайплайнов модели 2/2 </font></strike>
# </div>
# <div class="alert alert-danger">
# <br><font color='blue'>Что нужно исправить:</font><strike>
# <br><font color='crimson'> ❌ Сделать корректный размер выборки</font>
# </div>

# %% [markdown]
# <div class="well">
# <div class="alert alert-success">
# <font color='blue'><b>Итоговый комментарий ментора v2:</b></font>
# <br><font color='green'> ✔️ Большая часть замечаний учтена
# </font>
#     </div>
# <div class="alert alert-danger">
# <br><font color='blue'>Что нужно исправить:</font><strike>
# <br><font color='crimson'> ❌ Получить метрику ниже 6.8 за счет настройки лучшей модели</font>
# </div>

# %% [markdown]
# <div class="well">
# <div class="alert alert-success">
# <font color='blue'><b>Итоговый комментарий ментора v3:</b></font>
# <br><font color='green'> ✔️ Большая часть замечаний учтена
# </font>
#     </div>
# <div class="alert alert-danger">
# <br><font color='blue'>Что нужно исправить:</font><strike>
# <br><font color='crimson'> ❌ Повторение разбиения</font>
# <br><font color='crimson'> ❌ Убрать timeslplit</font>
# </div>

# %% [markdown]
# <div class="well">
# <div class="alert alert-success">
# <font color='blue'><b>Итоговый комментарий ментора v4:</b></font>
# <br><font color='green'> ✔️ Большая часть замечаний учтена
# </font>
#     </div>
# <div class="alert alert-danger">
# <br><font color='blue'>Что нужно исправить:</font><strike>
# <br><font color='crimson'> ❌ Вопрос про гиперпараметры
# </div>

# %% [markdown]
# <div class = 'well'>
# <font color='blue' size=5><b>Итоговый комментарий ментора по проекту V6</b></font>
#
# ---
# <font color='blue'> Алексей, было приятно смотреть твою работу, следить, как менялся твой код и становился проект лучше.
#
# <br> Что хочется отметить:
# <br>    1. Логика повествования и объяснение результатов.
# <br>    2. Оформление графиков для объяснения результатов. Визуальное представление проще распознается не-пограммистами. Правильные масштабы, названия и подписи показывают профессионализм аналитика.
#
# <br> Над чем нужно поработать:
# <br>    1. Подбор гиперпараметров при кросс-валидации. При работе с моделями важно знать много парамтеров, так как можно сделать модель под конкретную задачу и знать, что ее можно не переобучить для оптимальной работы.
# <br>    2. Создании конвеера(pipeline) для моделей. Очень часто нужно сделать коробочное решение для предсказания, которое можно завернуть в pipeline модель с последующей конвертацией в pickle файл.
# <br>    3. Создании функций для однотипных задач. Часто повторяющийся код можно обернуть в функцию, чтобы визуально было удобно работать с тетрадкой.
# <br>    4. Формирование разных датасетов для обучения моделей. Для каждого типа ансабля или базовой модели есть ограничения.
#
# <br> До новых встреч на поле Data Science и возможно в ODS. Удачи!
# </font>
